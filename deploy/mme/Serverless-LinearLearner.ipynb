# %% [markdown]
# # Amazon SageMaker Serverless using Linear Learner
# With [Amazon SageMaker Serverless ](https://docs.aws.amazon.com/sagemaker/latest/dg/serverless-endpoints.html), which is a purpose-built inference option that makes it easy for you to deploy and scale ML models. Serverless Inference is ideal for workloads which have idle periods between traffic spurts and can tolerate cold starts. Serverless endpoints automatically launch compute resources and scale them in and out depending on traffic, eliminating the need to choose instance types or manage scaling policies. This takes away the undifferentiated heavy lifting of selecting and managing servers. Serverless Inference integrates with AWS Lambda to offer you high availability, built-in fault tolerance and automatic scaling.
#
# With a pay-per-use model, Serverless Inference is a cost-effective option if you have an infrequent or unpredictable traffic pattern. During times when there are no requests, Serverless Inference scales your endpoint down to 0, helping you to minimize your costs.
#
# You can integrate Serverless Inference with your MLOps Pipelines to streamline your ML workflow, and you can use a serverless endpoint to host a model registered with Model Registry.
#
# This notebook showcases these capabilities
#
# To demonstrate these capabilities, the notebook discusses the use case of predicting house prices in multiple cities using linear regression.  House prices are predicted based on features like number of bedrooms, number of garages, square footage etc.  Depending on the city, the features affect the house price differently.  For example, small changes in the square footage cause a drastic change in house prices in New York when compared to price changes in Houston.  For accurate house price predictions, we will train multiple linear regression models, a unique location specific model per city.

# %% [markdown]
# ### Contents
#
# 1. [Generate synthetic data for housing models](#Generate-synthetic-data-for-housing-models)
# 1. [Preprocess the raw housing data using Scikit Learn model](#Preprocess-synthetic-housing-data-using-scikit-learn)
# 1. [Train multiple house value prediction models for multiple cities](#Train-multiple-house-value-prediction-models)
# 1. [Create model entity with multi model support](#Create-sagemaker-multi-model-support)
# 1. [Create an inference pipeline with sklearn model and MME linear learner model](#Create-inference-pipeline)
# 1. [Exercise the inference pipeline - Get predictions from the different  linear learner models](#Exercise-inference-pipeline)
# 1. [Update Multi Model Endpoint with new models](#update-models)
# 1. [Explore granular access to the target models of MME](#Finegrain-control-invoke-models)
# 1. [Endpoint CloudWatch Metrics Analysis](#CW-metric-analysis)
# 1. [Clean up](#CleanUp)

# %% [markdown]
# ## Section 1 - Generate synthetic data for housing models <a id='Generate-synthetic-data-for-housing-models'></a>
#
# In this section, you will generate synthetic data that will be used to train the linear learner models.  The data generated consists of 6 numerical features - the year the house was built in, house size in square feet, number of bedrooms, number of bathroom, the lot size and number of garages and two categorial features - deck and front_porch.

# %%
import numpy as np
import pandas as pd
import json
import datetime
import time
import boto3
import sagemaker
import os

from time import gmtime, strftime
from random import choice

from sagemaker import get_execution_role

from sagemaker.multidatamodel import MULTI_MODEL_CONTAINER_MODE
from sagemaker.multidatamodel import MultiDataModel

from sklearn.model_selection import train_test_split

# %%
NUM_HOUSES_PER_LOCATION = 1000
LOCATIONS  = ['NewYork_NY',    'LosAngeles_CA',   'Chicago_IL',    'Houston_TX',   'Dallas_TX',
              'Phoenix_AZ',    'Philadelphia_PA', 'SanAntonio_TX', 'SanDiego_CA',  'SanFrancisco_CA']
MAX_YEAR = 2019

# %%
def gen_price(house):
    """Generate price based on features of the house"""
    
    if house['FRONT_PORCH'] == 'y':
        garage = 1
    else:
        garage = 0
        
    if house['FRONT_PORCH'] == 'y':
        front_porch = 1
    else:
        front_porch = 0
        
    price = int(150 * house['SQUARE_FEET'] + \
                10000 * house['NUM_BEDROOMS'] + \
                15000 * house['NUM_BATHROOMS'] + \
                15000 * house['LOT_ACRES'] + \
                10000 * garage + \
                10000 * front_porch + \
                15000 * house['GARAGE_SPACES'] - \
                5000 * (MAX_YEAR - house['YEAR_BUILT']))
    return price

# %%
def gen_yes_no():
    """Generate values (y/n) for categorical features"""
    answer = choice(['y', 'n'])
    return answer

# %%
def gen_random_house():
    """Generate a row of data (single house information)"""
    house = {'SQUARE_FEET':    np.random.normal(3000, 750),
             'NUM_BEDROOMS':  np.random.randint(2, 7),
             'NUM_BATHROOMS': np.random.randint(2, 7) / 2,
             'LOT_ACRES':     round(np.random.normal(1.0, 0.25), 2),
             'GARAGE_SPACES': np.random.randint(0, 4),
             'YEAR_BUILT':    min(MAX_YEAR, int(np.random.normal(1995, 10))),
             'FRONT_PORCH':   gen_yes_no(),
             'DECK':          gen_yes_no()
            }
    
    price = gen_price(house)
    
    return [house['YEAR_BUILT'],   
            house['SQUARE_FEET'], 
            house['NUM_BEDROOMS'], 
            house['NUM_BATHROOMS'], 
            house['LOT_ACRES'],    
            house['GARAGE_SPACES'],
            house['FRONT_PORCH'],    
            house['DECK'], 
            price]

# %%
def gen_houses(num_houses):
    """Generate housing dataset"""
    house_list = []
    
    for _ in range(num_houses):
        house_list.append(gen_random_house())
        
    df = pd.DataFrame(
        house_list, 
        columns=[
            'YEAR_BUILT',    
            'SQUARE_FEET',  
            'NUM_BEDROOMS',            
            'NUM_BATHROOMS',
            'LOT_ACRES',
            'GARAGE_SPACES',
            'FRONT_PORCH',
            'DECK', 
            'PRICE']
    )
    return df

# %%
def save_data_locally(location, train, test): 
    """Save the housing data locally"""
    os.makedirs('data/{0}/train'.format(location), exist_ok=True)
    train.to_csv('data/{0}/train/train.csv'.format(location), sep=',', header=False, index=False)
       
    os.makedirs('data/{0}/test'.format(location), exist_ok=True)
    test.to_csv('data/{0}/test/test.csv'.format(location), sep=',', header=False, index=False)

# %%
#Generate housing data for multiple locations.
#Change "PARALLEL_TRAINING_JOBS " to a lower number to limit the number of training jobs and models. Or to a higher value to experiment with more models.

PARALLEL_TRAINING_JOBS = 1

for loc in LOCATIONS[:PARALLEL_TRAINING_JOBS]:
    houses = gen_houses(NUM_HOUSES_PER_LOCATION)
    
    #Spliting data into train and test in 90:10 ratio
    #Not splitting the train data into train and val because its not preprocessed yet
    train, test = train_test_split(houses, test_size=0.1)
    save_data_locally(loc, train, test)

# %%
#Shows the first few lines of data.
houses.head()

# %% [markdown]
# ## Section 2a ) Bring your own Model as tar ball in S3 <a id='Bring-your-own-model-as-tarball'></a>
# Here we will use the Tar ball as is and then create all the required artifacts from scratch
#     First we upload the Model tar ball to S3 to be used in our Transformer

# %%
sm_client = boto3.client(service_name='sagemaker')
runtime_sm_client = boto3.client(service_name='sagemaker-runtime')
sagemaker_session = sagemaker.Session()

s3 = boto3.resource('s3')
s3_client = boto3.client('s3')

BUCKET  = sagemaker_session.default_bucket()
print("BUCKET : ", BUCKET)

role = get_execution_role()
print("ROLE : ", role)

ACCOUNT_ID = boto3.client('sts').get_caller_identity()['Account']
REGION = boto3.Session().region_name

DATA_PREFIX = 'DEMO_MME_LINEAR_LEARNER'
HOUSING_MODEL_NAME = 'housing'
MULTI_MODEL_ARTIFACTS = 'multi_model_artifacts'
# Out:
# BUCKET :  sagemaker-us-east-1-333262794411
# ROLE :  arn:aws:iam::333262794411:role/CFN-SM-IM-Lambda-Catalog-SageMakerExecutionRole-9N675HOUZIM5

# %% [markdown]
# #### Upload the RAW data set to S3

# %%
#Upload the raw training data to S3 bucket, to be accessed by SKLearn
test_inputs = []
PARALLEL_TRAINING_JOBS=1
for loc in LOCATIONS[:PARALLEL_TRAINING_JOBS]:

    test_input = sagemaker_session.upload_data(
        path='./data/transform_output/use_for_test.csv'.format(loc),
        bucket=BUCKET,
        key_prefix='data/realtime/transform'
    )
    
    test_inputs.append(test_input)
    print("FINAL Test data uploaded to : ", test_input)
# Out:
# FINAL Test data uploaded to :  s3://sagemaker-us-east-1-333262794411/data/realtime/transform/use_for_test.csv

# %% [markdown]
# #### Upload the Model as tar ball into S3 location for use

# %%
# - UPLOAD the MODEL to S3
desired_model_s3 = 's3://{}/{}'.format(sagemaker_session.default_bucket(),'byom/scikit-learnestimator/model/realtime')
print(desired_model_s3)
model_s3_upload=sagemaker.s3.S3Uploader().upload(local_path='./models/realtime_linearlearner/model.tar.gz', desired_s3_uri=desired_model_s3,sagemaker_session=sagemaker_session)  
print(model_s3_upload)
# Out:
# s3://sagemaker-us-east-1-333262794411/byom/scikit-learnestimator/model/realtime
# s3://sagemaker-us-east-1-333262794411/byom/scikit-learnestimator/model/realtime/model.tar.gz

# %% [markdown]
# #### Create the REAL TIME Jobs:
#
# The steps to create the Job is straight forward
# * Create a Model object from the S3 location with the Image
# * Create a Model and a Real Time Serverless
# * Create a Serverless End Point
# * Run the Metrics test

# %%
# Retrieve the Container image
container = sagemaker.image_uris.retrieve(region=boto3.Session().region_name, framework="sklearn", version="0.20.0") # 0.23-1"
container = sagemaker.image_uris.retrieve(region=boto3.Session().region_name, framework='linear-learner')

# %%
print(f"using the model from s3={model_s3_upload}:")
# Out:
# using the model from s3=s3://sagemaker-us-east-1-333262794411/byom/scikit-learnestimator/model/realtime/model.tar.gz:

# %%
from sagemaker.model import Model
linear_model_name = "DEMO-SERVERLESS-LINEAR-" + time.strftime("%Y-%m-%d-%H-%M-%S", time.gmtime())

linear_model = Model(
    name=linear_model_name,
    model_data=model_s3_upload,  
    role=role,
    sagemaker_session=sagemaker_session,
    #entry_point="scripts/sklearn_preprocessor_batch.py",
    #framework_version="0.20.0", #"0.23-1", #"0.20.0",
    image_uri=container,
    #source_dir="scripts",
)
print(linear_model.source_dir)
print(linear_model.entry_point)
print(linear_model)
# Out:
# None
# None
# <sagemaker.model.Model object at 0x7f26ddeffc10>

# %% [markdown]
# #### Create Predictor
# we will use the predictor object to run our inference on the end points and
# also DEPOY the Model

# %%
csv_serializer = sagemaker.serializers.CSVSerializer()
csv_deserializer = sagemaker.deserializers.CSVDeserializer()


serverless_config = sagemaker.serverless.ServerlessInferenceConfig(
    memory_size_in_mb=4096, 
    max_concurrency=3
)

predictor = linear_model.deploy(
    initial_instance_count=1,
    instance_type="ml.m4.xlarge",
    serializer=csv_serializer,
    deserializer=csv_deserializer,
    endpoint_name=linear_model_name, # use the same name 
    wait=True,
    #async_inference_config=None,
    serverless_inference_config=serverless_config,
)
print(predictor)
# Out:
# -----!None

# %% [markdown]
# #### Create the Test Data set
# To be used to test for our Serverless interface

# %%
test_data_df = pd.read_csv('./data/transform_output/use_for_test.csv', header=None) # Has the Price column Removed -- ONLY Features 
print(test_data_df.shape)
test_data_df.head(2)
# Out:
# (900, 10)
#           0         1         2         3         4         5    6    7    8  \
# 0 -0.744936 -0.831786 -0.009418 -1.420279  0.106776 -1.312254  1.0  0.0  1.0
# 1 -1.136893  0.188842 -1.422126 -1.420279 -0.045943  0.451792  0.0  1.0  1.0
#
#      9
# 0  0.0
# 1  0.0

# %%
def predict_one_house_value_serverless(features, predictor_to_use):
    #print('SERVERLESS:to predict price of this house: {}'.format(features))
    body = ','.join(map(str, features)) + '\n'
    start_time = time.time()
     
    response = predictor_to_use.predict(features)
    #response_json = json.loads(response)
    #predicted_value = response_json['predictions'][0]['score']   
    predicted_value = float(response[0][0])
    
    duration = time.time() - start_time
    
    print('SEVERLESS:Price:of:house:${:.2f}, took {:,d} ms\n'.format(predicted_value, int(duration * 1000)))

# %% [markdown]
# #### Invoke 1st time
# we will see the time to invoke 1st time will be much longer

# %%
predictor = sagemaker.predictor.Predictor(
    sagemaker_session=sagemaker_session,
    serializer=csv_serializer,
    deserializer=csv_deserializer,
    endpoint_name=linear_model_name, # use the same name 

)
print(f"Predictor:created:={predictor}:")
# Out:
# Predictor:created:=<sagemaker.predictor.Predictor object at 0x7f26ddef6ee0>:

# %% [markdown]
# #### Run the serverless model

# %%
print("hello")
# Out:
# hello

# %%
# cell 15
# INVOKE the Predictor for the 1st time

predict_one_house_value_serverless(
    test_data_df.values.tolist()[0],  
    predictor
)
# Out:
# SEVERLESS:Price:of:house:$273472.94, took 7,058 ms

# %% [markdown]
# #### Now call it for the rest of all 900 rows to see the values
# we will iterate and send all 900 rows in but 1 by 1

# %%
for one_row in test_data_df.values.tolist():
    predict_one_house_value_serverless(one_row,  predictor)
    time.sleep(0.0005) # MINIMUM time to sleep -- so we should see the scale up of the serverless
# Out:
# SEVERLESS:Price:of:house:$273472.94, took 95 ms
#
# SEVERLESS:Price:of:house:$394512.62, took 123 ms
#
# SEVERLESS:Price:of:house:$443970.53, took 40 ms
#
# SEVERLESS:Price:of:house:$651414.62, took 45 ms
#
# SEVERLESS:Price:of:house:$358996.16, took 51 ms
#
# SEVERLESS:Price:of:house:$458998.72, took 45 ms
#
# SEVERLESS:Price:of:house:$339078.88, took 42 ms
#
# SEVERLESS:Price:of:house:$305665.94, took 39 ms
#
# SEVERLESS:Price:of:house:$596214.25, took 45 ms
#
# SEVERLESS:Price:of:house:$242778.41, took 42 ms
#
# SEVERLESS:Price:of:house:$434828.34, took 48 ms
#
# SEVERLESS:Price:of:house:$573561.00, took 53 ms
#
# SEVERLESS:Price:of:house:$274597.91, took 42 ms
#
# SEVERLESS:Price:of:house:$396197.97, took 891 ms
#
# SEVERLESS:Price:of:house:$387287.69, took 38 ms
#
# SEVERLESS:Price:of:house:$533519.12, took 41 ms
#
# SEVERLESS:Price:of:house:$187328.31, took 57 ms
#
# SEVERLESS:Price:of:house:$579758.44, took 42 ms
#
# SEVERLESS:Price:of:house:$486177.62, took 45 ms
#
# SEVERLESS:Price:of:house:$483680.66, took 40 ms
#
# SEVERLESS:Price:of:house:$441660.66, took 42 ms
#
# SEVERLESS:Price:of:house:$475851.41, took 43 ms
#
# SEVERLESS:Price:of:house:$453352.53, took 52 ms
#
# SEVERLESS:Price:of:house:$387209.56, took 43 ms
#
# SEVERLESS:Price:of:house:$618228.62, took 43 ms
#
# SEVERLESS:Price:of:house:$457132.56, took 749 ms
#
# SEVERLESS:Price:of:house:$640030.69, took 58 ms
#
# SEVERLESS:Price:of:house:$622637.44, took 40 ms
#
# SEVERLESS:Price:of:house:$525288.31, took 39 ms
#
# SEVERLESS:Price:of:house:$242597.45, took 41 ms
#
# SEVERLESS:Price:of:house:$542602.38, took 55 ms
#
# SEVERLESS:Price:of:house:$325793.19, took 40 ms
#
# SEVERLESS:Price:of:house:$408599.88, took 51 ms
#
# SEVERLESS:Price:of:house:$234835.97, took 41 ms
#
# SEVERLESS:Price:of:house:$310207.38, took 37 ms
#
# SEVERLESS:Price:of:house:$257306.88, took 40 ms
#
# SEVERLESS:Price:of:house:$390752.69, took 45 ms
#
# SEVERLESS:Price:of:house:$402483.47, took 685 ms
#
# SEVERLESS:Price:of:house:$449262.72, took 42 ms
#
# SEVERLESS:Price:of:house:$308879.94, took 53 ms
#
# SEVERLESS:Price:of:house:$628439.50, took 116 ms
#
# SEVERLESS:Price:of:house:$220137.12, took 42 ms
#
# SEVERLESS:Price:of:house:$462059.50, took 45 ms
#
# SEVERLESS:Price:of:house:$562241.31, took 40 ms
#
# SEVERLESS:Price:of:house:$472224.34, took 43 ms
#
# SEVERLESS:Price:of:house:$438311.34, took 44 ms
#
# SEVERLESS:Price:of:house:$570243.88, took 46 ms
#
# SEVERLESS:Price:of:house:$705674.62, took 38 ms
#
# SEVERLESS:Price:of:house:$497707.03, took 49 ms
#
# SEVERLESS:Price:of:house:$651868.44, took 39 ms
#
# SEVERLESS:Price:of:house:$610175.88, took 633 ms
#
# SEVERLESS:Price:of:house:$436696.22, took 47 ms
#
# SEVERLESS:Price:of:house:$536979.56, took 37 ms
#
# SEVERLESS:Price:of:house:$717770.00, took 38 ms
#
# SEVERLESS:Price:of:house:$482160.38, took 36 ms
#
# SEVERLESS:Price:of:house:$614858.00, took 37 ms
#
# SEVERLESS:Price:of:house:$644951.50, took 37 ms
#
# SEVERLESS:Price:of:house:$575607.44, took 38 ms
#
# SEVERLESS:Price:of:house:$357767.66, took 38 ms
#
# SEVERLESS:Price:of:house:$452281.28, took 37 ms
#
# SEVERLESS:Price:of:house:$371354.91, took 41 ms
#
# SEVERLESS:Price:of:house:$511984.03, took 41 ms
#
# SEVERLESS:Price:of:house:$651048.50, took 598 ms
#
# SEVERLESS:Price:of:house:$335039.31, took 47 ms
#
# SEVERLESS:Price:of:house:$331901.25, took 67 ms
#
# SEVERLESS:Price:of:house:$354281.84, took 38 ms
#
# SEVERLESS:Price:of:house:$559598.75, took 36 ms
#
# SEVERLESS:Price:of:house:$361568.84, took 44 ms
#
# SEVERLESS:Price:of:house:$452559.84, took 41 ms
#
# SEVERLESS:Price:of:house:$330268.94, took 45 ms
#
# SEVERLESS:Price:of:house:$544143.69, took 42 ms
#
# SEVERLESS:Price:of:house:$283463.06, took 38 ms
#
# SEVERLESS:Price:of:house:$461367.53, took 35 ms
#
# SEVERLESS:Price:of:house:$660761.25, took 38 ms
#
# SEVERLESS:Price:of:house:$560439.00, took 952 ms
#
# SEVERLESS:Price:of:house:$181267.69, took 51 ms
#
# SEVERLESS:Price:of:house:$452529.31, took 46 ms
#
# SEVERLESS:Price:of:house:$257819.50, took 40 ms
#
# SEVERLESS:Price:of:house:$329288.66, took 40 ms
#
# SEVERLESS:Price:of:house:$528752.88, took 39 ms
#
# SEVERLESS:Price:of:house:$309406.16, took 48 ms
#
# SEVERLESS:Price:of:house:$690584.12, took 39 ms
#
# SEVERLESS:Price:of:house:$321368.06, took 42 ms
#
# SEVERLESS:Price:of:house:$312909.31, took 40 ms
#
# SEVERLESS:Price:of:house:$370569.41, took 40 ms
#
# SEVERLESS:Price:of:house:$166371.88, took 41 ms
#
# SEVERLESS:Price:of:house:$770863.62, took 622 ms
#
# SEVERLESS:Price:of:house:$424380.59, took 40 ms
#
# SEVERLESS:Price:of:house:$407474.00, took 52 ms
#
# SEVERLESS:Price:of:house:$429067.59, took 39 ms
#
# SEVERLESS:Price:of:house:$508076.66, took 43 ms
#
# SEVERLESS:Price:of:house:$278241.81, took 47 ms
#
# SEVERLESS:Price:of:house:$592499.62, took 42 ms
#
# SEVERLESS:Price:of:house:$345960.59, took 38 ms
#
# SEVERLESS:Price:of:house:$580168.19, took 44 ms
#
# SEVERLESS:Price:of:house:$573779.94, took 44 ms
#
# SEVERLESS:Price:of:house:$444865.91, took 39 ms
#
# SEVERLESS:Price:of:house:$331678.56, took 38 ms
#
# SEVERLESS:Price:of:house:$520747.69, took 794 ms
#
# SEVERLESS:Price:of:house:$624040.50, took 41 ms
#
# SEVERLESS:Price:of:house:$470481.53, took 40 ms
#
# SEVERLESS:Price:of:house:$282864.75, took 44 ms
#
# SEVERLESS:Price:of:house:$504474.00, took 41 ms
#
# SEVERLESS:Price:of:house:$348438.06, took 50 ms
#
# SEVERLESS:Price:of:house:$170635.91, took 42 ms
#
# SEVERLESS:Price:of:house:$679186.94, took 39 ms
#
# SEVERLESS:Price:of:house:$545615.50, took 42 ms
#
# SEVERLESS:Price:of:house:$369188.00, took 41 ms
#
# SEVERLESS:Price:of:house:$541376.44, took 39 ms
#
# SEVERLESS:Price:of:house:$623239.00, took 45 ms
#
# SEVERLESS:Price:of:house:$464969.50, took 1,040 ms
#
# SEVERLESS:Price:of:house:$275774.81, took 45 ms
#
# SEVERLESS:Price:of:house:$448403.41, took 38 ms
#
# SEVERLESS:Price:of:house:$260440.62, took 41 ms
#
# SEVERLESS:Price:of:house:$452213.00, took 37 ms
#
# SEVERLESS:Price:of:house:$362752.50, took 41 ms
#
# SEVERLESS:Price:of:house:$527984.75, took 41 ms
#
# SEVERLESS:Price:of:house:$492024.75, took 37 ms
#
# SEVERLESS:Price:of:house:$414860.84, took 41 ms
#
# SEVERLESS:Price:of:house:$704527.94, took 38 ms
#
# SEVERLESS:Price:of:house:$444448.34, took 38 ms
#
# SEVERLESS:Price:of:house:$319802.47, took 39 ms
#
# SEVERLESS:Price:of:house:$426705.91, took 794 ms
#
# SEVERLESS:Price:of:house:$592363.81, took 43 ms
#
# SEVERLESS:Price:of:house:$471054.34, took 38 ms
#
# SEVERLESS:Price:of:house:$292921.06, took 44 ms
#
# SEVERLESS:Price:of:house:$260233.03, took 42 ms
#
# SEVERLESS:Price:of:house:$327412.25, took 43 ms
#
# SEVERLESS:Price:of:house:$417768.12, took 38 ms
#
# SEVERLESS:Price:of:house:$613633.19, took 39 ms
#
# SEVERLESS:Price:of:house:$559014.44, took 41 ms
#
# SEVERLESS:Price:of:house:$410730.66, took 40 ms
#
# SEVERLESS:Price:of:house:$564522.69, took 41 ms
#
# SEVERLESS:Price:of:house:$218724.45, took 39 ms
#
# SEVERLESS:Price:of:house:$376444.59, took 939 ms
#
# SEVERLESS:Price:of:house:$546064.56, took 40 ms
#
# SEVERLESS:Price:of:house:$452447.84, took 40 ms
#
# SEVERLESS:Price:of:house:$528760.12, took 38 ms
#
# SEVERLESS:Price:of:house:$402624.31, took 59 ms
#
# SEVERLESS:Price:of:house:$695870.50, took 38 ms
#
# SEVERLESS:Price:of:house:$347120.88, took 40 ms
#
# SEVERLESS:Price:of:house:$373059.50, took 71 ms
#
# SEVERLESS:Price:of:house:$336159.75, took 39 ms
#
# SEVERLESS:Price:of:house:$506182.59, took 39 ms
#
# SEVERLESS:Price:of:house:$433446.69, took 44 ms
#
# SEVERLESS:Price:of:house:$577553.25, took 44 ms
#
# SEVERLESS:Price:of:house:$787638.62, took 579 ms
#
# SEVERLESS:Price:of:house:$377690.94, took 38 ms
#
# SEVERLESS:Price:of:house:$672508.06, took 38 ms
#
# SEVERLESS:Price:of:house:$632323.81, took 37 ms
#
# SEVERLESS:Price:of:house:$193867.36, took 37 ms
#
# SEVERLESS:Price:of:house:$352487.06, took 44 ms
#
# SEVERLESS:Price:of:house:$408969.25, took 40 ms
#
# SEVERLESS:Price:of:house:$531669.25, took 41 ms
#
# SEVERLESS:Price:of:house:$489802.38, took 40 ms
#
# SEVERLESS:Price:of:house:$526973.38, took 38 ms
#
# SEVERLESS:Price:of:house:$368536.97, took 42 ms
#
# SEVERLESS:Price:of:house:$254375.03, took 48 ms
#
# SEVERLESS:Price:of:house:$442220.22, took 874 ms
#
# SEVERLESS:Price:of:house:$328340.50, took 85 ms
#
# SEVERLESS:Price:of:house:$457577.72, took 59 ms
#
# SEVERLESS:Price:of:house:$634751.31, took 44 ms
#
# SEVERLESS:Price:of:house:$432826.97, took 40 ms
#
# SEVERLESS:Price:of:house:$219295.22, took 39 ms
#
# SEVERLESS:Price:of:house:$518755.12, took 39 ms
#
# SEVERLESS:Price:of:house:$541406.94, took 40 ms
#
# SEVERLESS:Price:of:house:$340682.84, took 41 ms
#
# SEVERLESS:Price:of:house:$324177.44, took 42 ms
#
# SEVERLESS:Price:of:house:$623107.12, took 46 ms
#
# SEVERLESS:Price:of:house:$445190.56, took 42 ms
#
# SEVERLESS:Price:of:house:$375004.34, took 724 ms
#
# SEVERLESS:Price:of:house:$621203.19, took 46 ms
#
# SEVERLESS:Price:of:house:$433028.94, took 39 ms
#
# SEVERLESS:Price:of:house:$356756.41, took 44 ms
#
# SEVERLESS:Price:of:house:$429860.66, took 40 ms
#
# SEVERLESS:Price:of:house:$439836.38, took 40 ms
#
# SEVERLESS:Price:of:house:$538259.12, took 42 ms
#
# SEVERLESS:Price:of:house:$360851.41, took 36 ms
#
# SEVERLESS:Price:of:house:$518413.97, took 45 ms
#
# SEVERLESS:Price:of:house:$455422.56, took 36 ms
#
# SEVERLESS:Price:of:house:$360445.06, took 41 ms
#
# SEVERLESS:Price:of:house:$422023.94, took 38 ms
#
# SEVERLESS:Price:of:house:$380051.44, took 605 ms
#
# SEVERLESS:Price:of:house:$423592.50, took 38 ms
#
# SEVERLESS:Price:of:house:$485316.94, took 47 ms
#
# SEVERLESS:Price:of:house:$308946.25, took 38 ms
#
# SEVERLESS:Price:of:house:$404715.81, took 39 ms
#
# SEVERLESS:Price:of:house:$344677.06, took 48 ms
#
# SEVERLESS:Price:of:house:$368606.06, took 37 ms
#
# SEVERLESS:Price:of:house:$479522.31, took 40 ms
#
# SEVERLESS:Price:of:house:$512898.12, took 42 ms
#
# SEVERLESS:Price:of:house:$317014.25, took 40 ms
#
# SEVERLESS:Price:of:house:$375133.94, took 41 ms
#
# SEVERLESS:Price:of:house:$395309.34, took 41 ms
#
# SEVERLESS:Price:of:house:$419571.62, took 1,032 ms
#
# SEVERLESS:Price:of:house:$489621.62, took 42 ms
#
# SEVERLESS:Price:of:house:$422194.12, took 40 ms
#
# SEVERLESS:Price:of:house:$346750.00, took 42 ms
#
# SEVERLESS:Price:of:house:$170615.47, took 40 ms
#
# SEVERLESS:Price:of:house:$598025.25, took 41 ms
#
# SEVERLESS:Price:of:house:$578076.12, took 40 ms
#
# SEVERLESS:Price:of:house:$483934.59, took 46 ms
#
# SEVERLESS:Price:of:house:$618079.38, took 37 ms
#
# SEVERLESS:Price:of:house:$428507.34, took 119 ms
#
# SEVERLESS:Price:of:house:$428986.34, took 41 ms
#
# SEVERLESS:Price:of:house:$557173.88, took 48 ms
#
# SEVERLESS:Price:of:house:$379714.78, took 913 ms
#
# SEVERLESS:Price:of:house:$407501.41, took 40 ms
#
# SEVERLESS:Price:of:house:$708474.00, took 38 ms
#
# SEVERLESS:Price:of:house:$514506.88, took 34 ms
#
# SEVERLESS:Price:of:house:$437145.47, took 39 ms
#
# SEVERLESS:Price:of:house:$207863.58, took 36 ms
#
# SEVERLESS:Price:of:house:$416931.69, took 41 ms
#
# SEVERLESS:Price:of:house:$535761.06, took 37 ms
#
# SEVERLESS:Price:of:house:$327188.72, took 45 ms
#
# SEVERLESS:Price:of:house:$633850.06, took 40 ms
#
# SEVERLESS:Price:of:house:$581349.69, took 68 ms
#
# SEVERLESS:Price:of:house:$476715.97, took 46 ms
#
# SEVERLESS:Price:of:house:$384808.81, took 1,003 ms
#
# SEVERLESS:Price:of:house:$514696.78, took 36 ms
#
# SEVERLESS:Price:of:house:$454068.41, took 41 ms
#
# SEVERLESS:Price:of:house:$424523.22, took 38 ms
#
# SEVERLESS:Price:of:house:$569061.88, took 45 ms
#
# SEVERLESS:Price:of:house:$567520.12, took 45 ms
#
# SEVERLESS:Price:of:house:$403074.69, took 44 ms
#
# SEVERLESS:Price:of:house:$490120.22, took 41 ms
#
# SEVERLESS:Price:of:house:$438746.44, took 40 ms
#
# SEVERLESS:Price:of:house:$498016.12, took 40 ms
#
# SEVERLESS:Price:of:house:$229474.97, took 41 ms
#
# SEVERLESS:Price:of:house:$591636.25, took 48 ms
#
# SEVERLESS:Price:of:house:$442779.34, took 683 ms
#
# SEVERLESS:Price:of:house:$356542.44, took 36 ms
#
# SEVERLESS:Price:of:house:$610084.69, took 41 ms
#
# SEVERLESS:Price:of:house:$393216.59, took 48 ms
#
# SEVERLESS:Price:of:house:$347867.78, took 41 ms
#
# SEVERLESS:Price:of:house:$194252.88, took 42 ms
#
# SEVERLESS:Price:of:house:$585609.38, took 38 ms
#
# SEVERLESS:Price:of:house:$304375.19, took 40 ms
#
# SEVERLESS:Price:of:house:$693547.00, took 38 ms
#
# SEVERLESS:Price:of:house:$199568.27, took 40 ms
#
# SEVERLESS:Price:of:house:$360740.00, took 41 ms
#
# SEVERLESS:Price:of:house:$365418.41, took 41 ms
#
# SEVERLESS:Price:of:house:$471027.97, took 997 ms
#
# SEVERLESS:Price:of:house:$397485.66, took 38 ms
#
# SEVERLESS:Price:of:house:$338889.25, took 110 ms
#
# SEVERLESS:Price:of:house:$261256.81, took 47 ms
#
# SEVERLESS:Price:of:house:$570187.25, took 49 ms
#
# SEVERLESS:Price:of:house:$288401.38, took 37 ms
#
# SEVERLESS:Price:of:house:$622779.75, took 39 ms
#
# SEVERLESS:Price:of:house:$419488.78, took 34 ms
#
# SEVERLESS:Price:of:house:$482234.88, took 33 ms
#
# SEVERLESS:Price:of:house:$330023.97, took 41 ms
#
# SEVERLESS:Price:of:house:$628525.12, took 39 ms
#
# SEVERLESS:Price:of:house:$379888.38, took 41 ms
#
# SEVERLESS:Price:of:house:$445911.38, took 1,038 ms
#
# SEVERLESS:Price:of:house:$579655.06, took 42 ms
#
# SEVERLESS:Price:of:house:$624263.19, took 38 ms
#
# SEVERLESS:Price:of:house:$225145.77, took 36 ms
#
# SEVERLESS:Price:of:house:$345936.53, took 37 ms
#
# SEVERLESS:Price:of:house:$424534.84, took 38 ms
#
# SEVERLESS:Price:of:house:$542119.75, took 40 ms
#
# SEVERLESS:Price:of:house:$302012.00, took 41 ms
#
# SEVERLESS:Price:of:house:$627396.00, took 37 ms
#
# SEVERLESS:Price:of:house:$523566.69, took 41 ms
#
# SEVERLESS:Price:of:house:$394950.00, took 40 ms
#
# SEVERLESS:Price:of:house:$447097.91, took 40 ms
#
# SEVERLESS:Price:of:house:$122843.00, took 988 ms
#
# SEVERLESS:Price:of:house:$379403.06, took 40 ms
#
# SEVERLESS:Price:of:house:$606124.19, took 36 ms
#
# SEVERLESS:Price:of:house:$612050.94, took 35 ms
#
# SEVERLESS:Price:of:house:$457288.75, took 38 ms
#
# SEVERLESS:Price:of:house:$339545.94, took 40 ms
#
# SEVERLESS:Price:of:house:$497008.69, took 39 ms
#
# SEVERLESS:Price:of:house:$394783.69, took 43 ms
#
# SEVERLESS:Price:of:house:$314546.56, took 45 ms
#
# SEVERLESS:Price:of:house:$212725.23, took 33 ms
#
# SEVERLESS:Price:of:house:$534580.38, took 41 ms
#
# SEVERLESS:Price:of:house:$383427.06, took 38 ms
#
# SEVERLESS:Price:of:house:$376105.78, took 764 ms
#
# SEVERLESS:Price:of:house:$210552.25, took 45 ms
#
# SEVERLESS:Price:of:house:$315703.91, took 39 ms
#
# SEVERLESS:Price:of:house:$701088.38, took 42 ms
#
# SEVERLESS:Price:of:house:$422875.88, took 40 ms
#
# SEVERLESS:Price:of:house:$511954.62, took 44 ms
#
# SEVERLESS:Price:of:house:$597549.81, took 46 ms
#
# SEVERLESS:Price:of:house:$584279.69, took 39 ms
#
# SEVERLESS:Price:of:house:$378002.91, took 38 ms
#
# SEVERLESS:Price:of:house:$551407.81, took 39 ms
#
# SEVERLESS:Price:of:house:$491003.19, took 69 ms
#
# SEVERLESS:Price:of:house:$426562.53, took 46 ms
#
# SEVERLESS:Price:of:house:$545242.38, took 736 ms
#
# SEVERLESS:Price:of:house:$516896.50, took 41 ms
#
# SEVERLESS:Price:of:house:$335932.84, took 41 ms
#
# SEVERLESS:Price:of:house:$367405.88, took 43 ms
#
# SEVERLESS:Price:of:house:$287234.41, took 44 ms
#
# SEVERLESS:Price:of:house:$291979.38, took 48 ms
#
# SEVERLESS:Price:of:house:$593401.56, took 40 ms
#
# SEVERLESS:Price:of:house:$730524.25, took 42 ms
#
# SEVERLESS:Price:of:house:$502755.91, took 42 ms
#
# SEVERLESS:Price:of:house:$704723.25, took 37 ms
#
# SEVERLESS:Price:of:house:$562202.38, took 42 ms
#
# SEVERLESS:Price:of:house:$443191.53, took 38 ms
#
# SEVERLESS:Price:of:house:$659868.25, took 912 ms
#
# SEVERLESS:Price:of:house:$449808.56, took 37 ms
#
# SEVERLESS:Price:of:house:$519302.25, took 34 ms
#
# SEVERLESS:Price:of:house:$317363.94, took 55 ms
#
# SEVERLESS:Price:of:house:$443704.12, took 46 ms
#
# SEVERLESS:Price:of:house:$550226.75, took 48 ms
#
# SEVERLESS:Price:of:house:$639453.75, took 34 ms
#
# SEVERLESS:Price:of:house:$384733.88, took 38 ms
#
# SEVERLESS:Price:of:house:$373380.44, took 70 ms
#
# SEVERLESS:Price:of:house:$509553.28, took 40 ms
#
# SEVERLESS:Price:of:house:$370351.19, took 46 ms
#
# SEVERLESS:Price:of:house:$364734.81, took 37 ms
#
# SEVERLESS:Price:of:house:$461134.84, took 746 ms
#
# SEVERLESS:Price:of:house:$362646.62, took 38 ms
#
# SEVERLESS:Price:of:house:$329838.38, took 41 ms
#
# SEVERLESS:Price:of:house:$354400.00, took 42 ms
#
# SEVERLESS:Price:of:house:$355072.09, took 45 ms
#
# SEVERLESS:Price:of:house:$492942.75, took 89 ms
#
# SEVERLESS:Price:of:house:$462593.72, took 48 ms
#
# SEVERLESS:Price:of:house:$363114.84, took 40 ms
#
# SEVERLESS:Price:of:house:$443963.44, took 41 ms
#
# SEVERLESS:Price:of:house:$564613.62, took 39 ms
#
# SEVERLESS:Price:of:house:$402342.31, took 43 ms
#
# SEVERLESS:Price:of:house:$413501.06, took 43 ms
#
# SEVERLESS:Price:of:house:$536101.00, took 712 ms
#
# SEVERLESS:Price:of:house:$475707.69, took 97 ms
#
# SEVERLESS:Price:of:house:$433536.84, took 37 ms
#
# SEVERLESS:Price:of:house:$308682.47, took 48 ms
#
# SEVERLESS:Price:of:house:$362182.84, took 36 ms
#
# SEVERLESS:Price:of:house:$487332.81, took 40 ms
#
# SEVERLESS:Price:of:house:$610116.75, took 40 ms
#
# SEVERLESS:Price:of:house:$381468.69, took 37 ms
#
# SEVERLESS:Price:of:house:$385340.66, took 47 ms
#
# SEVERLESS:Price:of:house:$370145.41, took 41 ms
#
# SEVERLESS:Price:of:house:$456931.12, took 38 ms
#
# SEVERLESS:Price:of:house:$477634.28, took 40 ms
#
# SEVERLESS:Price:of:house:$498096.16, took 1,013 ms
#
# SEVERLESS:Price:of:house:$320809.06, took 40 ms
#
# SEVERLESS:Price:of:house:$578952.50, took 53 ms
#
# SEVERLESS:Price:of:house:$368048.75, took 46 ms
#
# SEVERLESS:Price:of:house:$354793.62, took 36 ms
#
# SEVERLESS:Price:of:house:$195893.28, took 47 ms
#
# SEVERLESS:Price:of:house:$561187.75, took 40 ms
#
# SEVERLESS:Price:of:house:$391480.88, took 56 ms
#
# SEVERLESS:Price:of:house:$711472.50, took 40 ms
#
# SEVERLESS:Price:of:house:$577725.88, took 41 ms
#
# SEVERLESS:Price:of:house:$403286.66, took 40 ms
#
# SEVERLESS:Price:of:house:$601666.38, took 41 ms
#
# SEVERLESS:Price:of:house:$544152.62, took 907 ms
#
# SEVERLESS:Price:of:house:$415764.66, took 39 ms
#
# SEVERLESS:Price:of:house:$480031.44, took 42 ms
# SEVERLESS:Price:of:house:$381158.94, took 37 ms
#
# SEVERLESS:Price:of:house:$487902.38, took 41 ms
#
# SEVERLESS:Price:of:house:$371840.59, took 34 ms
#
# SEVERLESS:Price:of:house:$450071.16, took 43 ms
#
# SEVERLESS:Price:of:house:$487399.84, took 68 ms
#
# SEVERLESS:Price:of:house:$352104.59, took 39 ms
#
# SEVERLESS:Price:of:house:$491518.38, took 37 ms
#
# SEVERLESS:Price:of:house:$467020.72, took 42 ms
#
# SEVERLESS:Price:of:house:$271993.81, took 41 ms
#
# SEVERLESS:Price:of:house:$236299.38, took 1,009 ms
#
# SEVERLESS:Price:of:house:$466719.69, took 41 ms
#
# SEVERLESS:Price:of:house:$564293.38, took 41 ms
#
# SEVERLESS:Price:of:house:$270806.12, took 39 ms
#
# SEVERLESS:Price:of:house:$481231.16, took 43 ms
#
# SEVERLESS:Price:of:house:$709056.44, took 37 ms
#
# SEVERLESS:Price:of:house:$567311.56, took 40 ms
#
# SEVERLESS:Price:of:house:$502641.78, took 42 ms
#
# SEVERLESS:Price:of:house:$451923.00, took 39 ms
#
# SEVERLESS:Price:of:house:$477797.50, took 54 ms
#
# SEVERLESS:Price:of:house:$437948.28, took 44 ms
#
# SEVERLESS:Price:of:house:$287720.25, took 39 ms
#
# SEVERLESS:Price:of:house:$583482.50, took 1,032 ms
#
# SEVERLESS:Price:of:house:$451083.09, took 37 ms
#
# SEVERLESS:Price:of:house:$252345.86, took 41 ms
#
# SEVERLESS:Price:of:house:$468578.41, took 46 ms
#
# SEVERLESS:Price:of:house:$345292.62, took 47 ms
#
# SEVERLESS:Price:of:house:$677007.44, took 56 ms
#
# SEVERLESS:Price:of:house:$432220.81, took 42 ms
#
# SEVERLESS:Price:of:house:$312275.59, took 42 ms
#
# SEVERLESS:Price:of:house:$536385.75, took 48 ms
#
# SEVERLESS:Price:of:house:$429056.81, took 40 ms
#
# SEVERLESS:Price:of:house:$406255.12, took 38 ms
#
# SEVERLESS:Price:of:house:$562145.88, took 39 ms
#
# SEVERLESS:Price:of:house:$325659.44, took 936 ms
#
# SEVERLESS:Price:of:house:$315800.34, took 37 ms
#
# SEVERLESS:Price:of:house:$431591.16, took 39 ms
#
# SEVERLESS:Price:of:house:$488729.22, took 38 ms
#
# SEVERLESS:Price:of:house:$413400.03, took 39 ms
#
# SEVERLESS:Price:of:house:$148705.84, took 43 ms
#
# SEVERLESS:Price:of:house:$497894.53, took 39 ms
#
# SEVERLESS:Price:of:house:$465150.09, took 34 ms
#
# SEVERLESS:Price:of:house:$328578.31, took 40 ms
#
# SEVERLESS:Price:of:house:$666183.38, took 40 ms
#
# SEVERLESS:Price:of:house:$529490.00, took 37 ms
#
# SEVERLESS:Price:of:house:$527961.44, took 34 ms
#
# SEVERLESS:Price:of:house:$502920.50, took 752 ms
#
# SEVERLESS:Price:of:house:$517226.94, took 52 ms
#
# SEVERLESS:Price:of:house:$500581.28, took 35 ms
#
# SEVERLESS:Price:of:house:$599047.88, took 39 ms
#
# SEVERLESS:Price:of:house:$348126.00, took 37 ms
#
# SEVERLESS:Price:of:house:$599139.19, took 48 ms
#
# SEVERLESS:Price:of:house:$567428.81, took 34 ms
#
# SEVERLESS:Price:of:house:$367747.50, took 37 ms
#
# SEVERLESS:Price:of:house:$628807.00, took 40 ms
#
# SEVERLESS:Price:of:house:$510578.62, took 43 ms
#
# SEVERLESS:Price:of:house:$396522.25, took 39 ms
#
# SEVERLESS:Price:of:house:$588297.44, took 38 ms
#
# SEVERLESS:Price:of:house:$388887.50, took 1,002 ms
#
# SEVERLESS:Price:of:house:$314160.25, took 44 ms
#
# SEVERLESS:Price:of:house:$442613.59, took 35 ms
#
# SEVERLESS:Price:of:house:$610372.25, took 41 ms
#
# SEVERLESS:Price:of:house:$583461.06, took 42 ms
#
# SEVERLESS:Price:of:house:$360612.69, took 44 ms
#
# SEVERLESS:Price:of:house:$192665.56, took 40 ms
#
# SEVERLESS:Price:of:house:$375488.75, took 36 ms
#
# SEVERLESS:Price:of:house:$389575.53, took 40 ms
#
# SEVERLESS:Price:of:house:$473227.31, took 37 ms
#
# SEVERLESS:Price:of:house:$406412.50, took 38 ms
#
# SEVERLESS:Price:of:house:$534062.88, took 39 ms
#
# SEVERLESS:Price:of:house:$440445.41, took 911 ms
#
# SEVERLESS:Price:of:house:$630699.50, took 39 ms
#
# SEVERLESS:Price:of:house:$577788.69, took 37 ms
#
# SEVERLESS:Price:of:house:$438795.06, took 37 ms
#
# SEVERLESS:Price:of:house:$467159.75, took 39 ms
#
# SEVERLESS:Price:of:house:$772262.06, took 37 ms
#
# SEVERLESS:Price:of:house:$364306.25, took 43 ms
#
# SEVERLESS:Price:of:house:$473667.94, took 37 ms
#
# SEVERLESS:Price:of:house:$483035.44, took 32 ms
#
# SEVERLESS:Price:of:house:$620890.81, took 39 ms
#
# SEVERLESS:Price:of:house:$573944.94, took 37 ms
#
# SEVERLESS:Price:of:house:$333411.25, took 39 ms
#
# SEVERLESS:Price:of:house:$313011.34, took 943 ms
#
# SEVERLESS:Price:of:house:$582186.75, took 39 ms
#
# SEVERLESS:Price:of:house:$387788.72, took 39 ms
#
# SEVERLESS:Price:of:house:$381709.56, took 37 ms
#
# SEVERLESS:Price:of:house:$357333.06, took 37 ms
#
# SEVERLESS:Price:of:house:$404686.75, took 35 ms
#
# SEVERLESS:Price:of:house:$452276.91, took 38 ms
#
# SEVERLESS:Price:of:house:$628958.25, took 40 ms
#
# SEVERLESS:Price:of:house:$564931.38, took 36 ms
#
# SEVERLESS:Price:of:house:$335509.53, took 39 ms
#
# SEVERLESS:Price:of:house:$601676.25, took 37 ms
#
# SEVERLESS:Price:of:house:$816605.81, took 39 ms
#
# SEVERLESS:Price:of:house:$240298.09, took 1,070 ms
#
# SEVERLESS:Price:of:house:$323502.69, took 40 ms
#
# SEVERLESS:Price:of:house:$78856.06, took 45 ms
#
# SEVERLESS:Price:of:house:$594622.69, took 67 ms
#
# SEVERLESS:Price:of:house:$495904.66, took 38 ms
#
#
# SEVERLESS:Price:of:house:$508351.69, took 39 ms
#
# SEVERLESS:Price:of:house:$375475.28, took 39 ms
#
# SEVERLESS:Price:of:house:$485033.38, took 40 ms
#
# SEVERLESS:Price:of:house:$511795.59, took 43 ms
#
# SEVERLESS:Price:of:house:$477743.59, took 36 ms
#
# SEVERLESS:Price:of:house:$404731.06, took 621 ms
#
# SEVERLESS:Price:of:house:$412845.75, took 41 ms
#
# SEVERLESS:Price:of:house:$254977.39, took 38 ms
#
# SEVERLESS:Price:of:house:$403605.69, took 41 ms
#
# SEVERLESS:Price:of:house:$366589.62, took 39 ms
#
# SEVERLESS:Price:of:house:$558337.81, took 42 ms
#
# SEVERLESS:Price:of:house:$548428.31, took 33 ms
#
# SEVERLESS:Price:of:house:$480942.22, took 40 ms
#
# SEVERLESS:Price:of:house:$506083.09, took 42 ms
#
# SEVERLESS:Price:of:house:$386891.75, took 89 ms
#
# SEVERLESS:Price:of:house:$161245.66, took 52 ms
#
# SEVERLESS:Price:of:house:$681174.00, took 39 ms
#
# SEVERLESS:Price:of:house:$315861.84, took 657 ms
#
# SEVERLESS:Price:of:house:$230892.84, took 38 ms
#
# SEVERLESS:Price:of:house:$388726.53, took 38 ms
#
# SEVERLESS:Price:of:house:$504594.00, took 54 ms
#
# SEVERLESS:Price:of:house:$514802.31, took 41 ms
#
# SEVERLESS:Price:of:house:$684925.38, took 44 ms
#
# SEVERLESS:Price:of:house:$257314.84, took 42 ms
#
# SEVERLESS:Price:of:house:$245257.34, took 46 ms
#
# SEVERLESS:Price:of:house:$382441.75, took 42 ms
#
# SEVERLESS:Price:of:house:$751777.81, took 38 ms
#
# SEVERLESS:Price:of:house:$385589.78, took 43 ms
#
# SEVERLESS:Price:of:house:$311710.66, took 40 ms
#
# SEVERLESS:Price:of:house:$368541.16, took 685 ms
#
# SEVERLESS:Price:of:house:$517633.03, took 39 ms
#
# SEVERLESS:Price:of:house:$415342.72, took 40 ms
#
# SEVERLESS:Price:of:house:$313204.31, took 47 ms
#
# SEVERLESS:Price:of:house:$626328.94, took 37 ms
#
# SEVERLESS:Price:of:house:$479217.06, took 53 ms
#
# SEVERLESS:Price:of:house:$564174.94, took 37 ms
#
# SEVERLESS:Price:of:house:$406521.88, took 39 ms
#
# SEVERLESS:Price:of:house:$487071.81, took 45 ms
#
# SEVERLESS:Price:of:house:$236317.44, took 39 ms
#
# SEVERLESS:Price:of:house:$299537.56, took 39 ms
#
# SEVERLESS:Price:of:house:$291748.06, took 40 ms
#
# SEVERLESS:Price:of:house:$594175.38, took 1,052 ms
#
# SEVERLESS:Price:of:house:$611680.19, took 38 ms
#
# SEVERLESS:Price:of:house:$592113.94, took 40 ms
#
# SEVERLESS:Price:of:house:$420165.91, took 37 ms
#
# SEVERLESS:Price:of:house:$502916.91, took 42 ms
#
# SEVERLESS:Price:of:house:$544231.38, took 40 ms
#
# SEVERLESS:Price:of:house:$407767.34, took 55 ms
#
# SEVERLESS:Price:of:house:$401521.31, took 42 ms
#
# SEVERLESS:Price:of:house:$452493.03, took 43 ms
#
# SEVERLESS:Price:of:house:$352443.47, took 40 ms
#
# SEVERLESS:Price:of:house:$267486.56, took 43 ms
#
# SEVERLESS:Price:of:house:$283659.06, took 42 ms
#
# SEVERLESS:Price:of:house:$442197.53, took 41 ms
#
# SEVERLESS:Price:of:house:$747091.00, took 1,042 ms
#
# SEVERLESS:Price:of:house:$632306.94, took 44 ms
#
# SEVERLESS:Price:of:house:$510528.25, took 51 ms
#
# SEVERLESS:Price:of:house:$442002.19, took 40 ms
#
# SEVERLESS:Price:of:house:$321585.06, took 42 ms
#
# SEVERLESS:Price:of:house:$558467.75, took 40 ms
#
# SEVERLESS:Price:of:house:$341055.69, took 40 ms
#
# SEVERLESS:Price:of:house:$480663.44, took 47 ms
#
# SEVERLESS:Price:of:house:$485862.00, took 38 ms
#
# SEVERLESS:Price:of:house:$519914.94, took 38 ms
#
# SEVERLESS:Price:of:house:$372734.62, took 45 ms
#
# SEVERLESS:Price:of:house:$287170.28, took 38 ms
#
# SEVERLESS:Price:of:house:$524298.12, took 679 ms
#
# SEVERLESS:Price:of:house:$255695.48, took 41 ms
#
# SEVERLESS:Price:of:house:$497178.56, took 50 ms
#
# SEVERLESS:Price:of:house:$374296.31, took 38 ms
#
# SEVERLESS:Price:of:house:$631923.19, took 35 ms
#
# SEVERLESS:Price:of:house:$459274.22, took 41 ms
#
# SEVERLESS:Price:of:house:$579223.19, took 45 ms
#
# SEVERLESS:Price:of:house:$277759.06, took 38 ms
#
# SEVERLESS:Price:of:house:$385356.81, took 40 ms
#
# SEVERLESS:Price:of:house:$400065.03, took 39 ms
#
# SEVERLESS:Price:of:house:$449938.25, took 37 ms
#
# SEVERLESS:Price:of:house:$561365.31, took 49 ms
#
# SEVERLESS:Price:of:house:$545874.06, took 870 ms
#
# SEVERLESS:Price:of:house:$533898.12, took 43 ms
#
# SEVERLESS:Price:of:house:$758950.88, took 45 ms
#
# SEVERLESS:Price:of:house:$498691.94, took 43 ms
#
# SEVERLESS:Price:of:house:$561602.19, took 39 ms
#
# SEVERLESS:Price:of:house:$440667.88, took 35 ms
#
# SEVERLESS:Price:of:house:$545604.69, took 49 ms
#
# SEVERLESS:Price:of:house:$410606.38, took 35 ms
#
# SEVERLESS:Price:of:house:$328553.94, took 36 ms
#
# SEVERLESS:Price:of:house:$386280.59, took 35 ms
#
# SEVERLESS:Price:of:house:$517385.16, took 41 ms
#
# SEVERLESS:Price:of:house:$348964.12, took 81 ms
#
# SEVERLESS:Price:of:house:$398939.59, took 997 ms
#
# SEVERLESS:Price:of:house:$395963.25, took 44 ms
#
# SEVERLESS:Price:of:house:$544662.50, took 42 ms
#
# SEVERLESS:Price:of:house:$423591.50, took 39 ms
#
# SEVERLESS:Price:of:house:$368116.00, took 38 ms
#
# SEVERLESS:Price:of:house:$499955.12, took 113 ms
#
# SEVERLESS:Price:of:house:$531761.94, took 44 ms
#
# SEVERLESS:Price:of:house:$579077.81, took 38 ms
#
# SEVERLESS:Price:of:house:$387823.31, took 35 ms
#
# SEVERLESS:Price:of:house:$308551.69, took 32 ms
#
# SEVERLESS:Price:of:house:$515596.69, took 35 ms
#
# SEVERLESS:Price:of:house:$458752.53, took 39 ms
#
# SEVERLESS:Price:of:house:$151423.06, took 804 ms
#
# SEVERLESS:Price:of:house:$320959.75, took 38 ms
#
# SEVERLESS:Price:of:house:$271492.62, took 40 ms
#
# SEVERLESS:Price:of:house:$475959.59, took 35 ms
#
# SEVERLESS:Price:of:house:$555166.12, took 82 ms
#
# SEVERLESS:Price:of:house:$341016.56, took 39 ms
#
# SEVERLESS:Price:of:house:$529504.12, took 38 ms
#
# SEVERLESS:Price:of:house:$762344.38, took 39 ms
#
# SEVERLESS:Price:of:house:$374450.78, took 41 ms
#
# SEVERLESS:Price:of:house:$530176.81, took 38 ms
#
# SEVERLESS:Price:of:house:$807796.88, took 43 ms
#
# SEVERLESS:Price:of:house:$446574.16, took 41 ms
#
# SEVERLESS:Price:of:house:$540549.69, took 892 ms
#
# SEVERLESS:Price:of:house:$487163.91, took 51 ms
#
# SEVERLESS:Price:of:house:$502028.97, took 34 ms
#
# SEVERLESS:Price:of:house:$544391.81, took 46 ms
#
# SEVERLESS:Price:of:house:$406537.03, took 36 ms
#
# SEVERLESS:Price:of:house:$315060.19, took 38 ms
#
# SEVERLESS:Price:of:house:$445152.56, took 38 ms
#
# SEVERLESS:Price:of:house:$295520.94, took 39 ms
#
# SEVERLESS:Price:of:house:$399109.56, took 40 ms
#
# SEVERLESS:Price:of:house:$234299.78, took 39 ms
#
# SEVERLESS:Price:of:house:$621840.25, took 38 ms
#
# SEVERLESS:Price:of:house:$499929.69, took 40 ms
#
# SEVERLESS:Price:of:house:$317020.41, took 755 ms
#
# SEVERLESS:Price:of:house:$470749.50, took 44 ms
#
# SEVERLESS:Price:of:house:$259061.58, took 42 ms
#
# SEVERLESS:Price:of:house:$368173.00, took 41 ms
#
# SEVERLESS:Price:of:house:$431081.88, took 63 ms
#
# SEVERLESS:Price:of:house:$550137.31, took 39 ms
#
# SEVERLESS:Price:of:house:$323075.56, took 39 ms
#
# SEVERLESS:Price:of:house:$293312.16, took 42 ms
#
# SEVERLESS:Price:of:house:$176693.53, took 41 ms
#
# SEVERLESS:Price:of:house:$413348.25, took 47 ms
#
# SEVERLESS:Price:of:house:$329371.78, took 44 ms
#
# SEVERLESS:Price:of:house:$617612.50, took 40 ms
#
# SEVERLESS:Price:of:house:$531886.25, took 947 ms
#
# SEVERLESS:Price:of:house:$372848.25, took 40 ms
#
# SEVERLESS:Price:of:house:$-49666.94, took 40 ms
#
# SEVERLESS:Price:of:house:$502291.75, took 43 ms
#
# SEVERLESS:Price:of:house:$565528.00, took 39 ms
#
# SEVERLESS:Price:of:house:$295714.19, took 40 ms
#
# SEVERLESS:Price:of:house:$673847.12, took 39 ms
#
# SEVERLESS:Price:of:house:$329412.69, took 39 ms
#
# SEVERLESS:Price:of:house:$322809.97, took 37 ms
#
# SEVERLESS:Price:of:house:$552083.12, took 40 ms
#
# SEVERLESS:Price:of:house:$457416.69, took 53 ms
#
# SEVERLESS:Price:of:house:$406767.44, took 43 ms
#
# SEVERLESS:Price:of:house:$220725.66, took 945 ms
#
# SEVERLESS:Price:of:house:$377123.25, took 43 ms
#
# SEVERLESS:Price:of:house:$498414.88, took 36 ms
#
# SEVERLESS:Price:of:house:$542111.38, took 37 ms
#
# SEVERLESS:Price:of:house:$296242.28, took 55 ms
#
# SEVERLESS:Price:of:house:$304448.31, took 38 ms
#
# SEVERLESS:Price:of:house:$484559.00, took 45 ms
#
# SEVERLESS:Price:of:house:$459682.03, took 36 ms
#
# SEVERLESS:Price:of:house:$378937.00, took 36 ms
#
# SEVERLESS:Price:of:house:$421779.91, took 44 ms
#
# SEVERLESS:Price:of:house:$310438.06, took 40 ms
#
# SEVERLESS:Price:of:house:$431622.19, took 66 ms
#
# SEVERLESS:Price:of:house:$433477.25, took 952 ms
#
# SEVERLESS:Price:of:house:$500610.47, took 40 ms
#
# SEVERLESS:Price:of:house:$443705.50, took 45 ms
#
# SEVERLESS:Price:of:house:$406001.00, took 37 ms
#
# SEVERLESS:Price:of:house:$552782.88, took 47 ms
#
# SEVERLESS:Price:of:house:$457195.38, took 43 ms
#
# SEVERLESS:Price:of:house:$348176.06, took 41 ms
#
# SEVERLESS:Price:of:house:$455333.72, took 40 ms
#
# SEVERLESS:Price:of:house:$302668.00, took 36 ms
#
# SEVERLESS:Price:of:house:$494623.62, took 38 ms
#
# SEVERLESS:Price:of:house:$645994.56, took 41 ms
#
# SEVERLESS:Price:of:house:$346684.09, took 42 ms
#
# SEVERLESS:Price:of:house:$479408.97, took 784 ms
#
# SEVERLESS:Price:of:house:$283082.78, took 36 ms
#
# SEVERLESS:Price:of:house:$293759.47, took 41 ms
#
# SEVERLESS:Price:of:house:$493297.59, took 48 ms
#
# SEVERLESS:Price:of:house:$593266.25, took 46 ms
#
# SEVERLESS:Price:of:house:$604610.12, took 40 ms
#
# SEVERLESS:Price:of:house:$533044.25, took 42 ms
#
# SEVERLESS:Price:of:house:$529180.50, took 42 ms
#
# SEVERLESS:Price:of:house:$510060.50, took 59 ms
#
# SEVERLESS:Price:of:house:$492051.81, took 41 ms
#
# SEVERLESS:Price:of:house:$430944.34, took 37 ms
#
# SEVERLESS:Price:of:house:$255540.09, took 39 ms
#
# SEVERLESS:Price:of:house:$432238.81, took 47 ms
#
# SEVERLESS:Price:of:house:$501168.81, took 952 ms
#
# SEVERLESS:Price:of:house:$596664.50, took 36 ms
#
# SEVERLESS:Price:of:house:$537975.00, took 34 ms
#
# SEVERLESS:Price:of:house:$433566.38, took 39 ms
#
# SEVERLESS:Price:of:house:$267352.00, took 41 ms
#
# SEVERLESS:Price:of:house:$479177.00, took 39 ms
#
# SEVERLESS:Price:of:house:$805875.38, took 37 ms
#
# SEVERLESS:Price:of:house:$771593.31, took 94 ms
#
# SEVERLESS:Price:of:house:$520417.34, took 42 ms
#
# SEVERLESS:Price:of:house:$450453.09, took 38 ms
#
# SEVERLESS:Price:of:house:$634668.25, took 40 ms
#
# SEVERLESS:Price:of:house:$483687.88, took 34 ms
#
# SEVERLESS:Price:of:house:$300547.75, took 951 ms
#
# SEVERLESS:Price:of:house:$402750.19, took 35 ms
#
# SEVERLESS:Price:of:house:$561903.88, took 38 ms
#
# SEVERLESS:Price:of:house:$621289.56, took 37 ms

# %% [markdown]
# #### This completes the serverless

# %% [markdown]
# ## Section 5 : Invoke using the Boto3 API model <a id='invoke-boto3'></a>

# %% [markdown]
# Set up the Boto3 client and invoke the end point

# %%
import boto3
client = boto3.client('sagemaker-runtime')
content_type = "text/csv"
features = test_data_df.values.tolist()[0]
payload = ','.join(map(str, features)) + '\n'
response = client.invoke_endpoint(
    EndpointName=linear_model_name,
    ContentType=content_type,
    Body=payload)
result = json.loads(response['Body'].read().decode())
print(result)
print(f"The Serverless:returned:Price:={result['predictions'][0]['score']}")

# %% [markdown]
# ## Section 6 - Endpoint CloudWatch Metrics Analysis <a id='CW-metric-analysis'></a>
#
#
# Amazon SageMaker provides CloudWatch metrics for  endpoints so you can determine the endpoint usage and the cache hit rate and optimize your endpoint.  To analyze the endpoint and the container behavior, you will invoke the model:
#
#     a. Create a Full 900 row data set
#     b. Invoke one by one row to generate traffic with no stop
#     c. Check cloud watch for instances and invocations
#
# We use this order of invocations to observe the behavior of the CloudWatch metrics - LoadedModelCount, MemoryUtilization and ModelCacheHit.  You are encouraged to experiment with loading varying number of models to use the CloudWatch charts to help make ongoing decisions on the optimal choice of instance type, instance count, and number of models that a given endpoint should host.

# %%
##Invoke multiple models in a loop
def invoke_multiple_model(model_range_low, model_range_high, features_list):
    for i in range(model_range_low, model_range_high):
        predict_one_house_value_serverless(features_list[i],  predictor)

# %%
##Starting with no models loaded into the container
##Invoke the first 100 models
invoke_multiple_model(10, 19, test_data_df.values.tolist())
# Out:
# SEVERLESS:Price:of:house:$434828.34, took 141 ms
#
# SEVERLESS:Price:of:house:$573561.00, took 39 ms
#
# SEVERLESS:Price:of:house:$274597.91, took 41 ms
#
# SEVERLESS:Price:of:house:$396197.97, took 38 ms
#
# SEVERLESS:Price:of:house:$387287.69, took 64 ms
#
# SEVERLESS:Price:of:house:$533519.12, took 45 ms
#
# SEVERLESS:Price:of:house:$187328.31, took 41 ms
#
# SEVERLESS:Price:of:house:$579758.44, took 38 ms
#
# SEVERLESS:Price:of:house:$486177.62, took 38 ms

# %% [markdown]
# #### Cloud watch Metrics
# ![](./cw_charts/Serverless_cloudwatch.png)

# %% [markdown]
# ## Clean up<a id='CleanUp'></a>
# Clean up the endpoint to avoid unneccessary costs.

# %%
#Delete the endpoint and underlying model
predictor.delete_model() 
predictor.delete_endpoint()
for t in preprocessor_transformers:
    t.delete_model()

# %%
#Delete the IAM Role
iam_client.detach_role_policy(
    PolicyArn=policy_arn,
    RoleName=role_name
)
iam_client.delete_role(RoleName=role_name)

# %%
#Delete the IAM Policy
iam_client.delete_policy(PolicyArn=policy_arn)
