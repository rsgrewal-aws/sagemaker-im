# %% [markdown]
# # Amazon SageMaker Multi-Model Endpoints using Linear Learner
# With [Amazon SageMaker multi-model endpoints](https://docs.aws.amazon.com/sagemaker/latest/dg/multi-model-endpoints.html), customers can create an endpoint that seamlessly hosts up to thousands of models. These endpoints are well suited to use cases where any one of a large number of models, which can be served from a common inference container, needs to be invokable on-demand and where it is acceptable for infrequently invoked models to incur some additional latency. For applications which require consistently low inference latency, a traditional endpoint is still the best choice.
#
# At a high level, Amazon SageMaker manages the loading and unloading of models for a multi-model endpoint, as they are needed. When an invocation request is made for a particular model, Amazon SageMaker routes the request to an instance assigned to that model, downloads the model artifacts from S3 onto that instance, and initiates loading of the model into the memory of the container. As soon as the loading is complete, Amazon SageMaker performs the requested invocation and returns the result. If the model is already loaded in memory on the selected instance, the downloading and loading steps are skipped and the invocation is performed immediately.
#
# Amazon SageMaker inference pipeline model consists of a sequence of containers that serve inference requests by combining preprocessing, predictions and post-processing data science tasks.  An inference pipeline allows you to apply the same preprocessing code used during model training, to process the inference request data used for predictions.
#
# To demonstrate how multi-model endpoints are created and used with inference pipeline, this notebook provides an example using a set of Linear Learner models that each predict housing prices for a single location. This domain is used as a simple example to easily experiment with multi-model endpoints.
#
# This notebook showcases three MME capabilities:
# * Native MME support with Amazon SageMaker Linear Learner algorithm.  Because of the native support there is no need for you to create a custom container.
# * Native MME support with Amazon SageMaker Inference Pipelines.
# * Granular InvokeModel access to multiple models hosted on the MME using IAM condition key.
#
# To demonstrate these capabilities, the notebook discusses the use case of predicting house prices in multiple cities using linear regression.  House prices are predicted based on features like number of bedrooms, number of garages, square footage etc.  Depending on the city, the features affect the house price differently.  For example, small changes in the square footage cause a drastic change in house prices in New York when compared to price changes in Houston.  For accurate house price predictions, we will train multiple linear regression models, a unique location specific model per city.

# %% [markdown]
# ### Contents
#
# 1. [Generate synthetic data for housing models](#Generate-synthetic-data-for-housing-models)
# 1. [Preprocess the raw housing data using Scikit Learn model](#Preprocess-synthetic-housing-data-using-scikit-learn)
# 1. [Train multiple house value prediction models for multiple cities](#Train-multiple-house-value-prediction-models)
# 1. [Create model entity with multi model support](#Create-sagemaker-multi-model-support)
# 1. [Create an inference pipeline with sklearn model and MME linear learner model](#Create-inference-pipeline)
# 1. [Exercise the inference pipeline - Get predictions from the different  linear learner models](#Exercise-inference-pipeline)
# 1. [Update Multi Model Endpoint with new models](#update-models)
# 1. [Explore granular access to the target models of MME](#Finegrain-control-invoke-models)
# 1. [Endpoint CloudWatch Metrics Analysis](#CW-metric-analysis)
# 1. [Clean up](#CleanUp)

# %% [markdown]
# ## Section 1 - Generate synthetic data for housing models <a id='Generate-synthetic-data-for-housing-models'></a>
#
# In this section, you will generate synthetic data that will be used to train the linear learner models.  The data generated consists of 6 numerical features - the year the house was built in, house size in square feet, number of bedrooms, number of bathroom, the lot size and number of garages and two categorial features - deck and front_porch.

# %%
import numpy as np
import pandas as pd
import json
import datetime
import time
import boto3
import sagemaker
import os

from time import gmtime, strftime
from random import choice

from sagemaker import get_execution_role

from sagemaker.multidatamodel import MULTI_MODEL_CONTAINER_MODE
from sagemaker.multidatamodel import MultiDataModel

from sklearn.model_selection import train_test_split

# %%
NUM_HOUSES_PER_LOCATION = 1000
LOCATIONS  = ['NewYork_NY',    'LosAngeles_CA',   'Chicago_IL',    'Houston_TX',   'Dallas_TX',
              'Phoenix_AZ',    'Philadelphia_PA', 'SanAntonio_TX', 'SanDiego_CA',  'SanFrancisco_CA']
MAX_YEAR = 2019

# %%
def gen_price(house):
    """Generate price based on features of the house"""
    
    if house['FRONT_PORCH'] == 'y':
        garage = 1
    else:
        garage = 0
        
    if house['FRONT_PORCH'] == 'y':
        front_porch = 1
    else:
        front_porch = 0
        
    price = int(150 * house['SQUARE_FEET'] + \
                10000 * house['NUM_BEDROOMS'] + \
                15000 * house['NUM_BATHROOMS'] + \
                15000 * house['LOT_ACRES'] + \
                10000 * garage + \
                10000 * front_porch + \
                15000 * house['GARAGE_SPACES'] - \
                5000 * (MAX_YEAR - house['YEAR_BUILT']))
    return price

# %%
def gen_yes_no():
    """Generate values (y/n) for categorical features"""
    answer = choice(['y', 'n'])
    return answer

# %%
def gen_random_house():
    """Generate a row of data (single house information)"""
    house = {'SQUARE_FEET':    np.random.normal(3000, 750),
             'NUM_BEDROOMS':  np.random.randint(2, 7),
             'NUM_BATHROOMS': np.random.randint(2, 7) / 2,
             'LOT_ACRES':     round(np.random.normal(1.0, 0.25), 2),
             'GARAGE_SPACES': np.random.randint(0, 4),
             'YEAR_BUILT':    min(MAX_YEAR, int(np.random.normal(1995, 10))),
             'FRONT_PORCH':   gen_yes_no(),
             'DECK':          gen_yes_no()
            }
    
    price = gen_price(house)
    
    return [house['YEAR_BUILT'],   
            house['SQUARE_FEET'], 
            house['NUM_BEDROOMS'], 
            house['NUM_BATHROOMS'], 
            house['LOT_ACRES'],    
            house['GARAGE_SPACES'],
            house['FRONT_PORCH'],    
            house['DECK'], 
            price]

# %%
def gen_houses(num_houses):
    """Generate housing dataset"""
    house_list = []
    
    for _ in range(num_houses):
        house_list.append(gen_random_house())
        
    df = pd.DataFrame(
        house_list, 
        columns=[
            'YEAR_BUILT',    
            'SQUARE_FEET',  
            'NUM_BEDROOMS',            
            'NUM_BATHROOMS',
            'LOT_ACRES',
            'GARAGE_SPACES',
            'FRONT_PORCH',
            'DECK', 
            'PRICE']
    )
    return df

# %%
def save_data_locally(location, train, test): 
    """Save the housing data locally"""
    os.makedirs('data/{0}/train'.format(location), exist_ok=True)
    train.to_csv('data/{0}/train/train.csv'.format(location), sep=',', header=False, index=False)
       
    os.makedirs('data/{0}/test'.format(location), exist_ok=True)
    test.to_csv('data/{0}/test/test.csv'.format(location), sep=',', header=False, index=False)

# %%
#Generate housing data for multiple locations.
#Change "PARALLEL_TRAINING_JOBS " to a lower number to limit the number of training jobs and models. Or to a higher value to experiment with more models.

PARALLEL_TRAINING_JOBS = 1

for loc in LOCATIONS[:PARALLEL_TRAINING_JOBS]:
    houses = gen_houses(NUM_HOUSES_PER_LOCATION)
    
    #Spliting data into train and test in 90:10 ratio
    #Not splitting the train data into train and val because its not preprocessed yet
    train, test = train_test_split(houses, test_size=0.1)
    save_data_locally(loc, train, test)

# %%
#Shows the first few lines of data.
houses.head()
# Out:
#    YEAR_BUILT  SQUARE_FEET  NUM_BEDROOMS  NUM_BATHROOMS  LOT_ACRES  \
# 0        2010  2733.746289             4            3.0       0.98
# 1        1991  2810.512529             4            3.0       1.17
# 2        2003  1569.772558             5            1.0       0.53
# 3        2010  4039.225689             5            2.5       1.29
# 4        2015  3894.031907             4            3.0       1.21
#
#    GARAGE_SPACES FRONT_PORCH DECK   PRICE
# 0              0           y    n  484761
# 1              1           n    y  399126
# 2              3           n    n  273415
# 3              3           n    y  712733
# 4              1           y    n  702254

# %% [markdown]
# ## Section 2 - Preprocess the raw housing data using Scikit Learn <a id='Preprocess-synthetic-housing-data-using-scikit-learn'></a>
#
# In this section, the categorical features of the data (deck and porch) are pre-processed using sklearn to convert them to one hot encoding representation.

# %%
sm_client = boto3.client(service_name='sagemaker')
runtime_sm_client = boto3.client(service_name='sagemaker-runtime')
sagemaker_session = sagemaker.Session()

s3 = boto3.resource('s3')
s3_client = boto3.client('s3')

BUCKET  = sagemaker_session.default_bucket()
print("BUCKET : ", BUCKET)

role = get_execution_role()
print("ROLE : ", role)

ACCOUNT_ID = boto3.client('sts').get_caller_identity()['Account']
REGION = boto3.Session().region_name

DATA_PREFIX = 'DEMO_MME_LINEAR_LEARNER'
HOUSING_MODEL_NAME = 'housing'
MULTI_MODEL_ARTIFACTS = 'multi_model_artifacts'
# Out:
# BUCKET :  sagemaker-us-east-1-622343165275
# ROLE :  arn:aws:iam::622343165275:role/service-role/AmazonSageMaker-ExecutionRole-20220208T115633

# %%
#Create the SKLearn estimator with the sklearn_preprocessor.py as the script
from sagemaker.sklearn.estimator import SKLearn

script_path = 'sklearn_preprocessor.py'

sklearn_estimator = SKLearn(
    entry_point=script_path,
    role=role,
    instance_type="ml.c4.xlarge",
    framework_version="0.20.0",
    sagemaker_session=sagemaker_session)

# %%
#Upload the raw training data to S3 bucket, to be accessed by SKLearn
train_inputs = []

for loc in LOCATIONS[:PARALLEL_TRAINING_JOBS]:

    train_input = sagemaker_session.upload_data(
        path='data/{}/train/train.csv'.format(loc),
        bucket=BUCKET,
        key_prefix='housing-data/{}/train'.format(loc)
    )
    
    train_inputs.append(train_input)
    print("Raw training data uploaded to : ", train_input)
# Out:
# Raw training data uploaded to :  s3://sagemaker-us-east-1-622343165275/housing-data/NewYork_NY/train/train.csv
# Raw training data uploaded to :  s3://sagemaker-us-east-1-622343165275/housing-data/LosAngeles_CA/train/train.csv
# Raw training data uploaded to :  s3://sagemaker-us-east-1-622343165275/housing-data/Chicago_IL/train/train.csv
# Raw training data uploaded to :  s3://sagemaker-us-east-1-622343165275/housing-data/Houston_TX/train/train.csv

# %%
##Launch multiple scikit learn training to process the raw synthetic data generated for multiple locations.
##Before executing this, take the training instance limits in your account and cost into consideration.

sklearn_estimators = []
sklearn_estimator_jobs = []

for index, loc in enumerate(LOCATIONS[:PARALLEL_TRAINING_JOBS]):
    print("sklearn_estimator fit input data at ", index , " for loc ", loc)
     
    job_name='scikit-learnestimator-{}'.format(strftime('%Y-%m-%d-%H-%M-%S', gmtime()))
    
    sklearn_estimator.fit({'train': train_inputs[index]}, job_name=job_name, wait=False)

    sklearn_estimators.append(sklearn_estimator)
    sklearn_estimator_jobs.append(job_name)
    
    time.sleep(1)
# Out:
# sklearn_estimator fit input data at  0  for loc  NewYork_NY

# %%
def wait_for_training_job_to_complete(job_name):
    """ Wait for the training job to complete """
    print('Waiting for job {} to complete...'.format(job_name))
    
    waiter = sm_client.get_waiter('training_job_completed_or_stopped')
    waiter.wait(TrainingJobName=job_name)

# %%
def wait_for_batch_transform_job_to_complete(job_name):
    """Wait for the batch transform job to complete"""
    print('Waiting for job {} to complete...'.format(job_name))
    
    waiter = sm_client.get_waiter('transform_job_completed_or_stopped')
    waiter.wait(TransformJobName=job_name)

# %%
#Wait for the preprocessor jobs to finish
for job_name in sklearn_estimator_jobs:
    wait_for_training_job_to_complete(job_name)
# Out:
# Waiting for job scikit-learnestimator-2022-08-01-06-18-59 to complete...

# %%
##Once the preprocessor is fit, use tranformer to preprocess the raw training data and store the transformed data right back into s3.
##Before executing this, take the training instance limits in your account and cost into consideration.

sklearn_estimator_transformers = []

for index, loc in enumerate(LOCATIONS[:PARALLEL_TRAINING_JOBS]):
    print("Transform the raw data at ", index , " for loc ", loc)
       
    sklearn_estimator = sklearn_estimators[index]
    
    transformer = sklearn_estimator.transformer(
        instance_count=1,
        instance_type='ml.m4.xlarge',
        assemble_with='Line',
        accept='text/csv'
    )
    
    sklearn_estimator_transformers.append(transformer)
# Out:
# Transform the raw data at  0  for loc  NewYork_NY

# %%
# Preprocess training input
preprocessed_train_data_path = []

for index, transformer in enumerate(sklearn_estimator_transformers):
    transformer.transform(train_inputs[index], content_type='text/csv')
    print('Launching batch transform job: {}'.format(transformer.latest_transform_job.job_name))
    preprocessed_train_data_path.append(transformer.output_path)
# Out:
# .....................

# %%
#Wait for all the batch transform jobs to finish
for transformer in sklearn_estimator_transformers: 
    job_name=transformer.latest_transform_job.job_name
    wait_for_batch_transform_job_to_complete(job_name)

# %%
##Download the preprocessed data, split into train and val, upload back to S3 in the same directory as tranformer output path
for index, transformer in enumerate(sklearn_estimator_transformers): 
    transformer_output_key='{}/{}'.format(transformer.latest_transform_job.job_name, 'train.csv.out') 
    
    preprocessed_data_download_dir = '{}/'.format("preprocessed-data/"+LOCATIONS[index])
    
    sagemaker_session.download_data(
        path=preprocessed_data_download_dir, 
        bucket=BUCKET,
        key_prefix=transformer_output_key
    )
    
    print('transformer_output_key: {}'.format(transformer_output_key ))
    print('Download directory: {}'.format(preprocessed_data_download_dir ))
    
    train_df = pd.read_csv('{}/{}'.format(preprocessed_data_download_dir,"train.csv.out"))
    
    #Spliting data into train and test in 70:30 ratio
    train, val = train_test_split(train_df, test_size=0.3)
    
    train.to_csv('{}{}'.format(preprocessed_data_download_dir,"train.csv"), sep=',', header=False, index=False)
    val.to_csv('{}{}'.format(preprocessed_data_download_dir,"val.csv"), sep=',', header=False, index=False)
    
    
    train_input = sagemaker_session.upload_data(
        path='{}/{}'.format(preprocessed_data_download_dir, 'train.csv'), 
        bucket=BUCKET,
        key_prefix='{}'.format(transformer.latest_transform_job.job_name, 'train.csv'))
    
    val_input = sagemaker_session.upload_data(
        path='{}/{}'.format(preprocessed_data_download_dir, 'val.csv'), 
        bucket=BUCKET,
        key_prefix='{}'.format(transformer.latest_transform_job.job_name, 'val.csv'))
# Out:
# transformer_output_key: sagemaker-scikit-learn-2022-07-30-17-48-18-639/train.csv.out
# Download directory: preprocessed-data/NewYork_NY/
# transformer_output_key: sagemaker-scikit-learn-2022-07-30-17-54-02-945/train.csv.out
# Download directory: preprocessed-data/LosAngeles_CA/
# transformer_output_key: sagemaker-scikit-learn-2022-07-30-18-00-49-395/train.csv.out
# Download directory: preprocessed-data/Chicago_IL/
# transformer_output_key: sagemaker-scikit-learn-2022-07-30-18-07-05-728/train.csv.out
# Download directory: preprocessed-data/Houston_TX/

# %%
##S3 location of the preprocessed data
for preprocessed_train_data in preprocessed_train_data_path: 
    print(preprocessed_train_data)
# Out:
# s3://sagemaker-us-east-1-582902858350/sagemaker-scikit-learn-2022-07-30-17-48-18-639
# s3://sagemaker-us-east-1-582902858350/sagemaker-scikit-learn-2022-07-30-17-54-02-945
# s3://sagemaker-us-east-1-582902858350/sagemaker-scikit-learn-2022-07-30-18-00-49-395
# s3://sagemaker-us-east-1-582902858350/sagemaker-scikit-learn-2022-07-30-18-07-05-728

# %%
for index, loc in enumerate(LOCATIONS[:PARALLEL_TRAINING_JOBS]):
    preprocessed_data_download_dir = '{}/'.format("preprocessed-data/"+LOCATIONS[index])
    path='{}/{}'.format(preprocessed_data_download_dir, 'train.csv')

# %% [markdown]
# ## Section 3 : Train house value prediction models for multiple cities <a id='Train-multiple-house-value-prediction-models'></a>
#
# In this section, you will use the preprocessed housing data to train multiple linear learner models.

# %%
container = sagemaker.image_uris.retrieve(region=boto3.Session().region_name, framework='linear-learner')

# %% [markdown]
# ### Launch a single training job for a given housing location
# There is nothing specific to multi-model endpoints in terms of the models it will host. They are trained in the same way as all other SageMaker models. Here we are using the Linear Learner estimator and not waiting for the job to complete.

# %%
def launch_training_job(location, transformer):
    """Launch a linear learner traing job"""
    
    train_inputs = '{}/{}'.format(transformer.output_path, "train.csv")
    val_inputs = '{}/{}'.format(transformer.output_path, "val.csv")
    
    print("train_inputs:", train_inputs)
    print("val_inputs:", val_inputs)
     
    full_output_prefix = '{}/model_artifacts/{}'.format(DATA_PREFIX, location)
    s3_output_path = 's3://{}/{}'.format(BUCKET, full_output_prefix)
    
    print("s3_output_path ", s3_output_path)
    
    s3_output_path = 's3://{}/{}/model_artifacts/{}'.format(BUCKET, DATA_PREFIX, location)
    
    linear_estimator = sagemaker.estimator.Estimator(
                            container,
                            role, 
                            instance_count=1,
                            instance_type='ml.c4.xlarge',
                            output_path=s3_output_path,
                            sagemaker_session=sagemaker_session)
    
    linear_estimator.set_hyperparameters(
                           feature_dim=10,
                           mini_batch_size=100,
                           predictor_type='regressor',
                           epochs=10,
                           num_models=32,
                           loss='absolute_loss')
    
    DISTRIBUTION_MODE = 'FullyReplicated'
    train_input = sagemaker.inputs.TrainingInput(s3_data=train_inputs,
                                     distribution=DISTRIBUTION_MODE, content_type='text/csv;label_size=1')
    val_input   = sagemaker.inputs.TrainingInput(s3_data=val_inputs,
                                     distribution=DISTRIBUTION_MODE, content_type='text/csv;label_size=1')
    
    remote_inputs = {'train': train_input, 'validation': val_input}
     
    linear_estimator.fit(remote_inputs, wait=False)
   
    return linear_estimator.latest_training_job.name

# %% [markdown]
# ### Kick off a model training job for each housing location

# %%
training_jobs = []
    
for transformer, loc in zip(sklearn_estimator_transformers, LOCATIONS[:PARALLEL_TRAINING_JOBS]): 
    job = launch_training_job(loc, transformer)
    training_jobs.append(job)
    
print('{} training jobs launched: {}'.format(len(training_jobs), training_jobs))
# Out:
# train_inputs: s3://sagemaker-us-east-1-582902858350/sagemaker-scikit-learn-2022-07-30-17-48-18-639/train.csv
# val_inputs: s3://sagemaker-us-east-1-582902858350/sagemaker-scikit-learn-2022-07-30-17-48-18-639/val.csv
# s3_output_path  s3://sagemaker-us-east-1-582902858350/DEMO_MME_LINEAR_LEARNER/model_artifacts/NewYork_NY
# train_inputs: s3://sagemaker-us-east-1-582902858350/sagemaker-scikit-learn-2022-07-30-17-54-02-945/train.csv
# val_inputs: s3://sagemaker-us-east-1-582902858350/sagemaker-scikit-learn-2022-07-30-17-54-02-945/val.csv
# s3_output_path  s3://sagemaker-us-east-1-582902858350/DEMO_MME_LINEAR_LEARNER/model_artifacts/LosAngeles_CA
# train_inputs: s3://sagemaker-us-east-1-582902858350/sagemaker-scikit-learn-2022-07-30-18-00-49-395/train.csv
# val_inputs: s3://sagemaker-us-east-1-582902858350/sagemaker-scikit-learn-2022-07-30-18-00-49-395/val.csv
# s3_output_path  s3://sagemaker-us-east-1-582902858350/DEMO_MME_LINEAR_LEARNER/model_artifacts/Chicago_IL
# train_inputs: s3://sagemaker-us-east-1-582902858350/sagemaker-scikit-learn-2022-07-30-18-07-05-728/train.csv
# val_inputs: s3://sagemaker-us-east-1-582902858350/sagemaker-scikit-learn-2022-07-30-18-07-05-728/val.csv
# s3_output_path  s3://sagemaker-us-east-1-582902858350/DEMO_MME_LINEAR_LEARNER/model_artifacts/Houston_TX
# 4 training jobs launched: ['linear-learner-2022-07-30-18-19-12-089', 'linear-learner-2022-07-30-18-19-12-411', 'linear-learner-2022-07-30-18-19-15-335', 'linear-learner-2022-07-30-18-19-17-389']

# %% [markdown]
# ### Wait for all  training jobs to finish

# %%
#Wait for the jobs to finish
for job_name in training_jobs:
    wait_for_training_job_to_complete(job_name)
# Out:
# Waiting for job linear-learner-2022-07-30-18-19-12-089 to complete...
# Waiting for job linear-learner-2022-07-30-18-19-12-411 to complete...
# Waiting for job linear-learner-2022-07-30-18-19-15-335 to complete...
# Waiting for job linear-learner-2022-07-30-18-19-17-389 to complete...

# %% [markdown]
# ## Section 4 - Create Sagemaker model with multi model support <a id='Create-sagemaker-multi-model-support'></a>

# %%
import re
def parse_model_artifacts(model_data_url):
    # extract the s3 key from the full url to the model artifacts
    s3_key = model_data_url.split('s3://{}/'.format(BUCKET))[1]
    # get the part of the key that identifies the model within the model artifacts folder
    model_name_plus = s3_key[s3_key.find('model_artifacts') + len('model_artifacts') + 1:]
    # finally, get the unique model name (e.g., "NewYork_NY")
    model_name = re.findall('^(.*?)/', model_name_plus)[0]
    return s3_key, model_name

# %%
# make a copy of the model artifacts from the original output of the training job to the place in
# s3 where the multi model endpoint will dynamically load individual models
def deploy_artifacts_to_mme(job_name):
    print("job_name :", job_name)
    response = sm_client.describe_training_job(TrainingJobName=job_name)
    source_s3_key, model_name = parse_model_artifacts(response['ModelArtifacts']['S3ModelArtifacts'])
    copy_source = {'Bucket': BUCKET, 'Key': source_s3_key}
    key = '{}/{}/{}/{}.tar.gz'.format(DATA_PREFIX, MULTI_MODEL_ARTIFACTS, model_name, model_name)
    
    print('Copying {} model\n   from: {}\n     to: {}...'.format(model_name, source_s3_key, key))
    s3_client.copy_object(Bucket=BUCKET, CopySource=copy_source, Key=key)

# %%
# First, clear out old versions of the model artifacts from previous runs of this notebook
s3_bucket = s3.Bucket(BUCKET)
full_input_prefix = '{}/multi_model_artifacts'.format(DATA_PREFIX)
print('Removing old model artifacts from {}'.format(full_input_prefix))
s3_bucket.objects.filter(Prefix=full_input_prefix + '/').delete()
# Out:
# Removing old model artifacts from DEMO_MME_LINEAR_LEARNER/multi_model_artifacts
# []

# %%
## Deploy all but the last model trained to MME
## We will use the last model to show how to update an existing MME in Section 7
for job_name in training_jobs[:-1]:
    deploy_artifacts_to_mme(job_name)
# Out:
# job_name : linear-learner-2022-07-30-18-19-12-089
# Copying NewYork_NY model
#    from: DEMO_MME_LINEAR_LEARNER/model_artifacts/NewYork_NY/linear-learner-2022-07-30-18-19-12-089/output/model.tar.gz
#      to: DEMO_MME_LINEAR_LEARNER/multi_model_artifacts/NewYork_NY/NewYork_NY.tar.gz...
# job_name : linear-learner-2022-07-30-18-19-12-411
# Copying LosAngeles_CA model
#    from: DEMO_MME_LINEAR_LEARNER/model_artifacts/LosAngeles_CA/linear-learner-2022-07-30-18-19-12-411/output/model.tar.gz
#      to: DEMO_MME_LINEAR_LEARNER/multi_model_artifacts/LosAngeles_CA/LosAngeles_CA.tar.gz...
# job_name : linear-learner-2022-07-30-18-19-15-335
# Copying Chicago_IL model
#    from: DEMO_MME_LINEAR_LEARNER/model_artifacts/Chicago_IL/linear-learner-2022-07-30-18-19-15-335/output/model.tar.gz
#      to: DEMO_MME_LINEAR_LEARNER/multi_model_artifacts/Chicago_IL/Chicago_IL.tar.gz...

# %%
MODEL_NAME = '{}-{}'.format(HOUSING_MODEL_NAME, strftime('%Y-%m-%d-%H-%M-%S', gmtime()))

_model_url  = 's3://{}/{}/{}/'.format(BUCKET, DATA_PREFIX, MULTI_MODEL_ARTIFACTS)

ll_multi_model = MultiDataModel(
        name=MODEL_NAME,
        model_data_prefix=_model_url,
        image_uri=container,
        role=role,
        sagemaker_session=sagemaker_session
    )

# %%
print(_model_url)
! aws s3 ls {_model_url}
# Out:
# s3://sagemaker-us-east-1-582902858350/DEMO_MME_LINEAR_LEARNER/multi_model_artifacts/
#                            PRE Chicago_IL/
#                            PRE Houston_TX/
#                            PRE LosAngeles_CA/
#                            PRE NewYork_NY/

# %% [markdown]
# ## Section 4 b: Create a Single Model (Pipeline Model ) as SERVERLESS for Inference
# Create a single model for serverless Inference

# %%
print(sklearn_estimator.model_data)
print(sklearn_estimator.image_uri)
# Out:
# s3://sagemaker-us-east-1-582902858350/scikit-learnestimator-2022-07-30-17-44-08/output/model.tar.gz
# 683313688378.dkr.ecr.us-east-1.amazonaws.com/sagemaker-scikit-learn:0.20.0-cpu-py3

# %%
from sagemaker.model import Model
from sagemaker.pipeline import PipelineModel
import boto3
from time import gmtime, strftime

timestamp_prefix = strftime("%Y-%m-%d-%H-%M-%S", gmtime())

#scikit_learn_inference_model = sklearn_estimator.create_model()

model_name = '{}-{}'.format('single-pipeline', timestamp_prefix)
endpoint_name = '{}-{}'.format('single-pipeline-ep', timestamp_prefix)
print(model_name)
print(endpoint_name)

sklearn_model = Model(
        name='{}-{}'.format("SinglePipelineTransformModel",timestamp_prefix),
        model_data=sklearn_estimator.model_data,
        image_uri=sklearn_estimator.image_uri,
        role=role,
        sagemaker_session=sagemaker_session
)

linear_learner_model_job = training_jobs[0]
source_s3_key = sm_client.describe_training_job(TrainingJobName=linear_learner_model_job)['ModelArtifacts']['S3ModelArtifacts']
print(source_s3_key)
linear_learner_model = Model(
        name='{}-{}'.format("SinglePipelineLinearModel",timestamp_prefix),
        model_data=source_s3_key,
        image_uri=container,
        role=role,
        sagemaker_session=sagemaker_session
    
)
sm_single_model = PipelineModel(
    name=model_name, 
    role=role, 
    sagemaker_session=sagemaker_session,
    models=[
        sklearn_model, 
        linear_learner_model])

print(linear_learner_model)
print(sklearn_model)
print(f"Finally:pipeline:model:created:={sm_single_model}::name={sm_single_model.name}::")
# Out:
# single-pipeline-2022-07-30-20-55-55
# single-pipeline-ep-2022-07-30-20-55-55
# s3://sagemaker-us-east-1-582902858350/DEMO_MME_LINEAR_LEARNER/model_artifacts/NewYork_NY/linear-learner-2022-07-30-18-19-12-089/output/model.tar.gz
# <sagemaker.model.Model object at 0x7f7b68c62a30>
# <sagemaker.model.Model object at 0x7f7b68c43820>
# Finally:pipeline:model:created:=<sagemaker.pipeline.PipelineModel object at 0x7f7b6bbb1a90>::name=single-pipeline-2022-07-30-20-55-55::

# %%
ServerlessConfig = {
        "MemorySizeInMB": 4096, # Endpoint memory in MB
        "MaxConcurrency": 1 # Number of concurrent invocations
}
serverlessConfig = sagemaker.serverless.ServerlessInferenceConfig(memory_size_in_mb=2048,max_concurrency=5)

linear_learner_model.deploy(
    serverless_inference_config = serverlessConfig, 
    endpoint_name=endpoint_name
)
# Out:
# ----------!

# %% [markdown]
# #### Create the Test Data set
# To be used to test for our Serverless interface

# %%
# Get the location of where the NY transformer job had finished writing the OUTPUT so we can use to test end point
s3_output_ny_transformer = '{}/train.csv'.format(sklearn_estimator_transformers[0].output_path)
print(s3_output_ny_transformer)
! mkdir -p data
data_test = sagemaker.s3.S3Downloader.download(s3_output_ny_transformer, './data')
test_data_df = pd.read_csv('./data/train.csv', header=None).iloc[:,1:] # Remove the price column
test_data_df.head(2)
# Out:
# s3://sagemaker-us-east-1-582902858350/sagemaker-scikit-learn-2022-07-30-17-48-18-639/train.csv
#          1         2         3         4         5         6    7    8    9   \
# 0 -1.060436  0.017998  0.721914  0.748629 -1.680885  0.462172  0.0  1.0  1.0
# 1  1.806883  0.433954  0.024038 -1.417821  0.189485  1.356699  1.0  0.0  1.0
#
#     10
# 0  0.0
# 1  0.0

# %%
def predict_one_house_value_serverless(features, predictor_to_use):
    print('SERVERLESS:to predict price of this house: {}'.format(features))
    body = ','.join(map(str, features)) + '\n'
    start_time = time.time()
     
    response = predictor_to_use.predict(features)
    
    response_json = json.loads(response)
        
    predicted_value = response_json['predictions'][0]['score']    
    
    duration = time.time() - start_time
    
    print('SEVERLESS::${:,.2f}, took {:,d} ms\n'.format(predicted_value, int(duration * 1000)))

# %% [markdown]
# #### Create Predictor
# we will use the predictor object to run our inference on the end points

# %%
# cell 14
#Create Predictor
from sagemaker.predictor import Predictor

csv_serializer = sagemaker.serializers.CSVSerializer()

predictor_serverless = Predictor(
    endpoint_name=endpoint_name,
    sagemaker_session=sagemaker_session,
    serializer=csv_serializer
)

# %% [markdown]
# #### Invoke 1st time
# we will see the time to invoke 1st time will be much longer

# %%
# cell 15
# INVOKE the Predictor for the 1st time

predict_one_house_value_serverless(test_data_df.values.tolist()[0],  predictor_serverless)
# Out:
# SERVERLESS:to predict price of this house: [-1.0604358195543646, 0.0179978290324503, 0.7219139052495401, 0.748628600716049, -1.6808850975610778, 0.4621720706554826, 0.0, 1.0, 1.0, 0.0]
# SEVERLESS::$415,305.56, took 10,989 ms

# %% [markdown]
# #### Now call it for the rest of all 900 rows to see the values
# we will iterate and send all 900 rows in but 1 by 1

# %%
for one_row in test_data_df.values.tolist():
    predict_one_house_value_serverless(one_row,  predictor_serverless)
    time.sleep(0.005) # MINIMUM time to sleep -- so we should see the scale up of the serverless
# Out:
# SERVERLESS:to predict price of this house: [-1.0604358195543646, 0.0179978290324503, 0.7219139052495401, 0.748628600716049, -1.6808850975610778, 0.4621720706554826, 0.0, 1.0, 1.0, 0.0]
# SEVERLESS::
 0.0, 1.0, 1.0, 0.0]
# SEVERLESS::$565,780.75, took 42 ms
#
# SERVERLESS:to predict price of this house: [0.0015339563429694, 0.0658455979988136, -0.6738380060814719, -0.6956709505046244, -2.054959040200436, 0.4621720706554826, 1.0, 0.0, 0.0, 1.0]
# SEVERLESS::$418,599.59, took 43 ms
#
# SERVERLESS:to predict price of this house: [-1.0604358195543646, -0.1800380549440623, -1.3717139617469778, -0.6956709505046244, 0.4388672440619537, 0.4621720706554826, 0.0, 1.0, 1.0, 0.0]
# SEVERLESS::$360,295.94, took 43 ms
#
# SERVERLESS:to predict price of this house: [2.656458396086305, -0.8317458645319059, 0.7219139052495401, 0.0264788251057123, -0.3508444126211365, 1.356698659020933, 0.0, 1.0, 0.0, 1.0]
# SEVERLESS::$517,227.44, took 45 ms
#
# SERVERLESS:to predict price of this house: [0.6387158218813699, -0.6527010272062621, -0.6738380060814719, -0.6956709505046244, 1.4779615291712829, 0.4621720706554826, 1.0, 0.0, 1.0, 0.0]
# SEVERLESS::$382,643.62, took 40 ms
#
# SERVERLESS:to predict price of this house: [1.5944886201889703, -0.9852140243921446, 0.0240379495840341, 0.748628600716049, 1.0623238151275507, -1.326881106075418, 1.0, 0.0, 0.0, 1.0]

# %% [markdown]
# #### This completes the serverless

# %% [markdown]
# ## Section 5 : Create an inference pipeline with sklearn model and MME linear learner model <a id='Create-inference-pipeline'></a>

# %% [markdown]
# Set up the inference pipeline using the Pipeline Model API.  This sets up a list of models in a single endpoint; In this example, we configure our pipeline model with the fitted Scikit-learn inference model and the fitted Linear Learner model.

# %%
from sagemaker.model import Model
from sagemaker.pipeline import PipelineModel
import boto3
from time import gmtime, strftime

timestamp_prefix = strftime("%Y-%m-%d-%H-%M-%S", gmtime())

scikit_learn_inference_model = sklearn_estimator.create_model()

model_name = '{}-{}'.format('inference-pipeline', timestamp_prefix)
endpoint_name = '{}-{}'.format('inference-pipeline-ep', timestamp_prefix)

print(model_name)
print(endpoint_name)
# Out:
# inference-pipeline-2022-07-30-18-26-02
# inference-pipeline-ep-2022-07-30-18-26-02

# %%
sm_model = PipelineModel(
    name=model_name, 
    role=role, 
    sagemaker_session=sagemaker_session,
    models=[
        scikit_learn_inference_model, 
        ll_multi_model])

sm_model.deploy(initial_instance_count=1, instance_type='ml.m4.xlarge', endpoint_name=endpoint_name)
# Out:
# ---------------------!

# %% [markdown]
# ## Section 6 :  Exercise the inference pipeline - Get predictions from  different  linear learner models. <a id='Exercise-inference-pipeline'></a>

# %%
#Create Predictor
from sagemaker.predictor import Predictor

csv_serializer = sagemaker.serializers.CSVSerializer()

predictor = Predictor(
    endpoint_name=endpoint_name,
    sagemaker_session=sagemaker_session,
    serializer=csv_serializer)

# %%
def predict_one_house_value(features, model_name, predictor_to_use):
    print('Using model {} to predict price of this house: {}'.format(model_name,
                                                                     features))
    body = ','.join(map(str, features)) + '\n'
    start_time = time.time()
     
    response = predictor_to_use.predict(features, target_model=model_name)
    
    response_json = json.loads(response)
        
    predicted_value = response_json['predictions'][0]['score']    
    
    duration = time.time() - start_time
    
    print('${:,.2f}, took {:,d} ms\n'.format(predicted_value, int(duration * 1000)))

# %% [markdown]
# ## Pipeline Model
# Since we have the Pipeline Model -- it will convert the values to Numerical and then pass to the Linear Learner

# %%
for _ in range(10):
    model_name = LOCATIONS[np.random.randint(1, PARALLEL_TRAINING_JOBS - 1)]
    full_model_name = '{}/{}.tar.gz'.format(model_name,model_name)
    predict_one_house_value(gen_random_house()[:-1], full_model_name, predictor)
# Out:
# Using model Chicago_IL/Chicago_IL.tar.gz to predict price of this house: [2002, 2323.4190202621903, 4, 3.0, 0.66, 1, 'n', 'n']
# $370,795.16, took 41 ms
#
# Using model LosAngeles_CA/LosAngeles_CA.tar.gz to predict price of this house: [1985, 2581.0913056917657, 6, 2.5, 1.08, 1, 'n', 'y']
# $343,427.19, took 45 ms
#
# Using model Chicago_IL/Chicago_IL.tar.gz to predict price of this house: [1996, 2661.7014949443815, 5, 2.5, 1.31, 2, 'y', 'y']
# $439,165.09, took 40 ms
#
# Using model LosAngeles_CA/LosAngeles_CA.tar.gz to predict price of this house: [1993, 2934.579262160833, 6, 2.5, 0.96, 3, 'n', 'n']
# $467,756.91, took 39 ms
#
# Using model LosAngeles_CA/LosAngeles_CA.tar.gz to predict price of this house: [1984, 3635.2703165326084, 3, 2.5, 1.32, 2, 'n', 'y']
# $489,612.06, took 40 ms
#
# Using model LosAngeles_CA/LosAngeles_CA.tar.gz to predict price of this house: [1985, 3325.933340550506, 4, 2.5, 0.68, 3, 'y', 'n']
# $486,198.22, took 46 ms
#
# Using model LosAngeles_CA/LosAngeles_CA.tar.gz to predict price of this house: [2003, 3677.7290674114697, 2, 1.5, 0.97, 2, 'y', 'y']
# $579,232.31, took 38 ms
#
# Using model Chicago_IL/Chicago_IL.tar.gz to predict price of this house: [1996, 4128.562142393982, 2, 3.0, 0.65, 3, 'n', 'n']
# $622,689.56, took 40 ms
#
# Using model Chicago_IL/Chicago_IL.tar.gz to predict price of this house: [1985, 2679.9954990281494, 4, 1.0, 0.86, 0, 'n', 'y']
# $297,567.44, took 54 ms
#
# Using model LosAngeles_CA/LosAngeles_CA.tar.gz to predict price of this house: [1996, 3291.7770124051726, 2, 3.0, 0.87, 1, 'n', 'y']
# $473,626.84, took 38 ms

# %% [markdown]
# ## Section 7 - Add new model to the endpoint, simply by copying the model artifact to the S3 location
# <a id='update-models'></a>

# %%
## Copy the last model
last_training_job=training_jobs[PARALLEL_TRAINING_JOBS-1]
deploy_artifacts_to_mme(last_training_job)
# Out:
# job_name : linear-learner-2022-07-30-18-19-17-389
# Copying Houston_TX model
#    from: DEMO_MME_LINEAR_LEARNER/model_artifacts/Houston_TX/linear-learner-2022-07-30-18-19-17-389/output/model.tar.gz
#      to: DEMO_MME_LINEAR_LEARNER/multi_model_artifacts/Houston_TX/Houston_TX.tar.gz...

# %%
model_name = LOCATIONS[PARALLEL_TRAINING_JOBS-1]
full_model_name = '{}/{}.tar.gz'.format(model_name,model_name)
predict_one_house_value(gen_random_house()[:-1], full_model_name, predictor)
# Out:
# Using model Houston_TX/Houston_TX.tar.gz to predict price of this house: [1999, 2573.0677935054773, 6, 2.5, 1.13, 1, 'n', 'y']
# $416,380.50, took 1,773 ms

# %% [markdown]
# ## Section 8 - Endpoint CloudWatch Metrics Analysis <a id='CW-metric-analysis'></a>
#
# With MME, the models are dynamically loaded into the container’s memory of the instance hosting the endpoint when invoked.  Therefore, the model invocation may take longer when it is invoked for the first time. And after the model is already in the container’s memory, the subsequent invocations will be faster. If an instance memory utilization is high and a new model needs to be loaded then unused models are unloaded.  The unloaded models will remain in the instance’s storage volume and can be loaded into container’s memory later without being downloaded from the S3 bucket again.  If the instance’s storage volume if full, unused models are deleted from storage volume.
# Managing the loading/unloading of the models is completely handled by Amazon SageMaker behind the scenes without you having to take any specific actions.  However, it is important to understand this behavior because it has implications on the model invocation latency.
#
# Amazon SageMaker provides CloudWatch metrics for multi-model endpoints so you can determine the endpoint usage and the cache hit rate and optimize your endpoint.  To analyze the endpoint and the container behavior, you will invoke multiple models in this order :
#
#     a. Create 200 copies of the original model and save with different names.
#     b. Starting with no models loaded into the container, Invoke the first 100 models
#     c. Invoke the same 100 models again
DEMO_MME_LINEAR_LEARNER/multi_model_artifacts/LosAngeles_CA/LosAngeles_CA.tar.gz
#      to: DEMO_MME_LINEAR_LEARNER/multi_model_artifacts/LosAngeles_CA/199_LosAngeles_CA.tar.gz...

# %%
##Invoke multiple models in a loop
def invoke_multiple_models_mme(model_range_low, model_range_high):
    for i in range(model_range_low, model_range_high):
        new_model_name="{}_{}".format(i, model_name)
        full_model_name = '{}/{}.tar.gz'.format(model_name, new_model_name)
        predict_one_house_value(gen_random_house()[:-1], full_model_name, predictor)

# %%
##Starting with no models loaded into the container
##Invoke the first 100 models
invoke_multiple_models_mme(10, 19)
# Out:
# Using model LosAngeles_CA/10_LosAngeles_CA.tar.gz to predict price of this house: [1980, 2630.417358186317, 2, 3.0, 0.89, 2, 'n', 'n']
# $316,281.12, took 111 ms
#
# Using model LosAngeles_CA/11_LosAngeles_CA.tar.gz to predict price of this house: [2004, 2532.154642472635, 5, 1.0, 0.7, 3, 'n', 'n']
# $425,994.47, took 35 ms
#
# Using model LosAngeles_CA/12_LosAngeles_CA.tar.gz to predict price of this house: [1993, 2507.8760778662336, 6, 2.0, 1.28, 1, 'y', 'y']
# $386,309.94, took 38 ms
#
# Using model LosAngeles_CA/13_LosAngeles_CA.tar.gz to predict price of this house: [1989, 3276.129949947519, 5, 1.0, 1.22, 1, 'n', 'n']
# $445,425.00, took 37 ms
#
# Using model LosAngeles_CA/14_LosAngeles_CA.tar.gz to predict price of this house: [2000, 3754.2717218010575, 5, 1.0, 0.73, 3, 'y', 'n']
# $611,343.38, took 36 ms
#
# Using model LosAngeles_CA/15_LosAngeles_CA.tar.gz to predict price of this house: [2002, 3502.729681953635, 4, 1.0, 0.68, 2, 'n', 'n']
# $540,053.50, took 1,752 ms
#
# Using model LosAngeles_CA/16_LosAngeles_CA.tar.gz to predict price of this house: [1989, 1868.1698065447447, 5, 1.5, 0.82, 3, 'y', 'n']
# $281,423.31, took 1,696 ms
#
# Using model LosAngeles_CA/17_LosAngeles_CA.tar.gz to predict price of this house: [1984, 2526.114914484797, 4, 1.0, 1.61, 0, 'n', 'n']
# $290,845.53, took 1,599 ms
#
# Using model LosAngeles_CA/18_LosAngeles_CA.tar.gz to predict price of this house: [1993, 2729.1896878127045, 2, 2.0, 1.04, 0, 'y', 'n']
# $373,300.94, took 1,650 ms

# %%
##Invoke the same 100 models again
invoke_multiple_models_mme(10, 19)
# Out:
# Using model LosAngeles_CA/10_LosAngeles_CA.tar.gz to predict price of this house: [2012, 3095.645635941488, 5, 1.5, 0.63, 2, 'y', 'y']
# $555,757.88, took 92 ms
#
# Using model LosAngeles_CA/11_LosAngeles_CA.tar.gz to predict price of this house: [1997, 3602.0626081069004, 2, 3.0, 0.51, 0, 'y', 'n']
# $531,267.69, took 37 ms
#
# Using model LosAngeles_CA/12_LosAngeles_CA.tar.gz to predict price of this house: [1994, 2982.3300561526653, 4, 2.0, 0.71, 3, 'y', 'n']
# $471,046.44, took 34 ms
#
# Using model LosAngeles_CA/13_LosAngeles_CA.tar.gz to predict price of this house: [2012, 4297.702397436577, 5, 2.0, 0.55, 3, 'y', 'y']
# $757,625.38, took 34 ms
#
# Using model LosAngeles_CA/14_LosAngeles_CA.tar.gz to predict price of this house: [2006, 2345.815774582077, 4, 1.0, 0.98, 0, 'y', 'y']
# $374,487.84, took 34 ms
#
# Using model LosAngeles_CA/15_LosAngeles_CA.tar.gz to predict price of this house: [1988, 3411.8552018471264, 6, 2.5, 1.2, 1, 'n', 'n']
# $491,144.12, took 33 ms
#
# Using model LosAngeles_CA/16_LosAngeles_CA.tar.gz to predict price of this house: [1998, 2306.9712281424727, 6, 3.0, 1.25, 2, 'n', 'n']
# $394,522.69, took 34 ms
#
# Using model LosAngeles_CA/17_LosAngeles_CA.tar.gz to predict price of this house: [2012, 3047.075126804451, 5, 1.0, 1.34, 1, 'n', 'y']
# $518,159.50, took 34 ms
#
# Using model LosAngeles_CA/18_LosAngeles_CA.tar.gz to predict price of this house: [1987, 3331.45929963914, 3, 1.0, 0.73, 1, 'n', 'y']
# $413,738.91, took 35 ms

# %%
##This time invoke all 200 models to observe behavior
invoke_multiple_models_mme(0, 200)
# Out:
# Using model LosAngeles_CA/0_LosAngeles_CA.tar.gz to predict price of this house: [1971, 3732.2316829051088, 6, 1.0, 1.03, 2, 'n', 'y']
# $441,344.97, took 1,755 ms
#
# Using model LosAngeles_CA/1_LosAngeles_CA.tar.gz to predict price of this house: [1990, 3039.4853221253043, 5, 2.0, 0.99, 0, 'y', 'y']
# $425,153.44, took 1,648 ms
#
# Using model LosAngeles_CA/2_LosAngeles_CA.tar.gz to predict price of this house: [1969, 2847.596067368888, 2, 2.5, 1.05, 0, 'y', 'y']
# $276,559.28, took 1,627 ms
#
# Using model LosAngeles_CA/3_LosAngeles_CA.tar.gz to predict price of this house: [1995, 2888.9437416393266, 6, 3.0, 0.73, 1, 'y', 'n']
# $465,717.44, took 1,671 ms
#
# Using model LosAngeles_CA/4_LosAngeles_CA.tar.gz to predict price of this house: [2014, 3157.0516821635883, 6, 1.0, 0.95, 1, 'y', 'y']
# $566,843.31, took 1,648 ms
#
# Using model LosAngeles_CA/5_LosAngeles_CA.tar.gz to predict price of this house: [1990, 3747.722982515914, 5, 3.0, 1.33, 3, 'n', 'y']
# $574,431.94, took 1,599 ms
#
# Using model LosAngeles_CA/6_LosAngeles_CA.tar.gz to predict price of this house: [1990, 2549.9079276381576, 5, 3.0, 0.76, 3, 'n', 'n']
# $390,661.91, took 1,674 ms
#
# Using model LosAngeles_CA/7_LosAngeles_CA.tar.gz to predict price of this house: [2002, 3496.344883186732, 6, 1.5, 1.18, 2, 'n', 'n']
# $571,036.62, took 1,655 ms
#
# Using model LosAngeles_CA/8_LosAngeles_CA.tar.gz to predict price of this house: [1989, 2962.7741069428666, 5, 2.0, 1.15, 0, 'n', 'n']
# $397,392.72, took 1,619 ms
#
# Using model LosAngeles_CA/9_LosAngeles_CA.tar.gz to predict price of this house: [1986, 2349.2290445088415, 6, 2.0, 0.85, 2, 'y', 'y']
# $336,118.19, took 1,675 ms
#
# Using model LosAngeles_CA/10_LosAngeles_CA.tar.gz to predict price of this house: [1985, 3671.951142499327, 2, 2.0, 0.99, 1, 'n', 'n']
# $470,961.44, took 1,648 ms
#
# Using model LosAngeles_CA/11_LosAngeles_CA.tar.gz to predict price of this house: [1998, 1848.5586651663, 6, 1.5, 0.74, 0, 'y', 'y']
# $281,552.25, took 1,675 ms
#
# Using model LosAngeles_CA/12_LosAngeles_CA.tar.gz to predict price of this house: [1991, 2696.9492018664564, 3, 1.0, 0.87, 0, 'y', 'n']
# $350,440.56, took 1,650 ms
#
# Using model LosAngeles_CA/13_LosAngeles_CA.tar.gz to predict price of this house: [1997, 3432.131161826791, 5, 1.0, 1.09, 2, 'n', 'n']
# $519,893.81, took 1,649 ms
#
# Using model LosAngeles_CA/14_LosAngeles_CA.tar.gz to predict price of this house: [1993, 3424.0238241795028, 3, 1.5, 1.06, 1, 'n', 'n']
# $474,689.50, took 1,698 ms
#
# Using model LosAngeles_CA/15_LosAngeles_CA.tar.gz to predict price of this house: [1979, 3903.5755802307267, 4, 3.0, 0.72, 3, 'n', 'n']
# $532,828.56, took 1,630 ms
#
# Using model LosAngeles_CA/16_LosAngeles_CA.tar.gz to predict price of this house: [1974, 3952.4157764801635, 2, 1.5, 1.57, 3, 'n', 'n']
# $489,579.19, took 1,618 ms
#
# Using model LosAngeles_CA/17_LosAngeles_CA.tar.gz to predict price of this house: [1985, 3416.5529494605844, 3, 3.0, 1.11, 2, 'y', 'n']
# $490,763.88, took 1,703 ms
#
# Using model LosAngeles_CA/18_LosAngeles_CA.tar.gz to predict price of this house: [1996, 3640.4797967378663, 5, 3.0, 0.34, 0, 'y', 'y']
# $549,918.50, took 1,648 ms
#
# Using model LosAngeles_CA/19_LosAngeles_CA.tar.gz to predict price of this house: [2003, 3683.429604637818, 4, 2.0, 1.62, 0, 'y', 'n']
# $591,932.00, took 1,699 ms
#
# Using model LosAngeles_CA/20_LosAngeles_CA.tar.gz to predict price of this house: [2005, 2581.4316351348925, 6, 2.0, 0.97, 1, 'n', 'n']
# $437,274.00, took 1,673 ms
#
# Using model LosAngeles_CA/21_LosAngeles_CA.tar.gz to predict price of this house: [2002, 3221.642096568456, 3, 3.0, 0.92, 3, 'n', 'n']
# $535,392.12, took 1,650 ms
#
# Using model LosAngeles_CA/22_LosAngeles_CA.tar.gz to predict price of this house: [2003, 2828.8041690586556, 6, 1.5, 1.07, 3, 'n', 'y']
# $481,580.81, took 1,723 ms
#
# Using model LosAngeles_CA/23_LosAngeles_CA.tar.gz to predict price of this house: [1980, 2674.736115425838, 3, 2.0, 0.91, 3, 'y', 'n']
# $351,030.44, took 1,672 ms
#
# Using model LosAngeles_CA/24_LosAngeles_CA.tar.gz to predict price of this house: [1997, 1841.8732750626607, 5, 2.5, 1.48, 1, 'n', 'n']
# $292,806.72, took 1,623 ms
#
# Using model LosAngeles_CA/25_LosAngeles_CA.tar.gz to predict price of this house: [2000, 3719.644792566046, 4, 2.5, 0.53, 0, 'n', 'n']
# $554,499.50, took 1,623 ms
#
# Using model LosAngeles_CA/26_LosAngeles_CA.tar.gz to predict price of this house: [1995, 3206.7959401867133, 5, 1.0, 0.87, 2, 'y', 'y']
# $486,564.72, took 1,681 ms
#
# Using model LosAngeles_CA/27_LosAngeles_CA.tar.gz to predict price of this house: [2004, 1717.925007070829, 5, 1.5, 1.02, 1, 'n', 'n']
# $286,710.06, took 1,681 ms
#
# Using model LosAngeles_CA/28_LosAngeles_CA.tar.gz to predict price of this house: [2001, 3056.7805593445237, 2, 2.0, 0.71, 0, 'y', 'y']
# $450,906.88, took 1,636 ms
#
# Using model LosAngeles_CA/29_LosAngeles_CA.tar.gz to predict price of this house: [2012, 2639.1423166968616, 5, 2.5, 0.85, 0, 'y', 'y']
# $476,310.56, took 1,599 ms
#
# Using model LosAngeles_CA/30_LosAngeles_CA.tar.gz to predict price of this house: [1991, 3950.363991350228, 5, 2.5, 1.01, 2, 'n', 'y']
# $583,898.00, took 1,675 ms
#
# Using model LosAngeles_CA/31_LosAngeles_CA.tar.gz to predict price of this house: [1981, 3034.568280734601, 2, 1.0, 1.08, 0, 'n', 'n']
# $328,033.25, took 1,655 ms
#
# Using model LosAngeles_CA/32_LosAngeles_CA.tar.gz to predict price of this house: [1971, 1811.866760907913, 3, 3.0, 0.64, 0, 'y', 'n']
# $145,238.94, took 1,643 ms
#
# Using model LosAngeles_CA/33_LosAngeles_CA.tar.gz to predict price of this house: [1993, 2217.2398245147715, 6, 3.0, 1.09, 1, 'y', 'y']
# $353,997.81, took 1,699 ms
#
# Using model LosAngeles_CA/34_LosAngeles_CA.tar.gz to predict price of this house: [1992, 1239.1952838030634, 4, 1.0, 0.72, 3, 'y', 'n']
# $183,475.66, took 1,652 ms
#
# Using model LosAngeles_CA/35_LosAngeles_CA.tar.gz to predict price of this house: [2007, 5513.141677702359, 2, 2.0, 1.16, 1, 'y', 'y']
# $872,117.81, took 1,704 ms
#
# Using model LosAngeles_CA/36_LosAngeles_CA.tar.gz to predict price of this house: [2009, 3729.038168334918, 5, 3.0, 1.03, 1, 'y', 'y']
# $650,536.50, took 1,665 ms
#
# Using model LosAngeles_CA/37_LosAngeles_CA.tar.gz to predict price of this house: [1999, 2500.563015564526, 2, 3.0, 0.76, 0, 'y', 'n']
# $378,090.78, took 1,654 ms
#
# Using model LosAngeles_CA/38_LosAngeles_CA.tar.gz to predict price of this house: [1979, 3419.8861872307934, 4, 1.5, 1.01, 3, 'y', 'y']
# $455,993.69, took 1,624 ms
#
# Using model LosAngeles_CA/39_LosAngeles_CA.tar.gz to predict price of this house: [2013, 2374.1312538453403, 5, 2.5, 0.99, 0, 'n', 'n']
# $429,466.09, took 1,695 ms
#
# Using model LosAngeles_CA/40_LosAngeles_CA.tar.gz to predict price of this house: [1993, 3481.279135716933, 6, 1.5, 0.98, 1, 'n', 'y']
# $502,363.44, took 1,624 ms
#
# Using model LosAngeles_CA/41_LosAngeles_CA.tar.gz to predict price of this house: [1990, 3720.4985417858325, 3, 2.0, 1.06, 3, 'n', 'n']
# $540,336.19, took 1,626 ms
#
# Using model LosAngeles_CA/42_LosAngeles_CA.tar.gz to predict price of this house: [1973, 3739.582636397473, 3, 2.0, 0.64, 1, 'n', 'n']
# $426,558.75, took 1,649 ms
#
# Using model LosAngeles_CA/43_LosAngeles_CA.tar.gz to predict price of this house: [2004, 3731.2271374374413, 6, 3.0, 1.42, 3, 'n', 'y']
# $649,732.19, took 1,599 ms
#
# Using model LosAngeles_CA/44_LosAngeles_CA.tar.gz to predict price of this house: [1987, 3017.8648701736397, 2, 2.5, 0.71, 3, 'y', 'y']
# $426,627.03, took 1,627 ms
#
# Using model LosAngeles_CA/45_LosAngeles_CA.tar.gz to predict price of this house: [1979, 3164.2159070238954, 6, 2.5, 0.91, 1, 'y', 'n']
# $425,296.75, took 1,621 ms
#
# Using model LosAngeles_CA/46_LosAngeles_CA.tar.gz to predict price of this house: [1985, 3430.504620904789, 6, 1.0, 1.29, 0, 'y', 'y']
# $458,721.66, took 1,649 ms
#
# Using model LosAngeles_CA/47_LosAngeles_CA.tar.gz to predict price of this house: [1997, 3148.669752324896, 2, 1.5, 1.01, 0, 'y', 'y']
# $442,645.75, took 1,626 ms
#
# Using model LosAngeles_CA/48_LosAngeles_CA.tar.gz to predict price of this house: [1990, 2229.2936027507753, 3, 3.0, 1.02, 3, 'y', 'n']
# $348,176.78, took 1,623 ms
#
# Using model LosAngeles_CA/49_LosAngeles_CA.tar.gz to predict price of this house: [2000, 3024.8818774156966, 5, 3.0, 1.47, 3, 'y', 'n']
# $540,893.94, took 1,655 ms
#
# Using model LosAngeles_CA/50_LosAngeles_CA.tar.gz to predict price of this house: [1980, 2528.2986348493955, 2, 3.0, 0.76, 1, 'n', 'y']
# $279,065.62, took 1,641 ms
#
# Using model LosAngeles_CA/51_LosAngeles_CA.tar.gz to predict price of this house: [1995, 1597.6640086237792, 3, 2.0, 1.11, 3, 'y', 'n']
# $263,764.25, took 1,650 ms
#
# Using model LosAngeles_CA/52_LosAngeles_CA.tar.gz to predict price of this house: [1988, 3570.8084393956756, 6, 1.0, 0.56, 2, 'y', 'n']
# $517,574.91, took 1,676 ms
#
# Using model LosAngeles_CA/53_LosAngeles_CA.tar.gz to predict price of this house: [2000, 3312.133044582858, 6, 2.0, 1.33, 2, 'y', 'y']
# $556,624.44, took 1,596 ms
#
# Using model LosAngeles_CA/54_LosAngeles_CA.tar.gz to predict price of this house: [1986, 3007.106437000332, 6, 2.5, 0.65, 3, 'n', 'n']
# $440,237.22, took 1,676 ms
#
# Using model LosAngeles_CA/55_LosAngeles_CA.tar.gz to predict price of this house: [1998, 3078.6636518125656, 5, 2.5, 0.84, 3, 'n', 'y']
# $497,529.66, took 1,626 ms
#
# Using model LosAngeles_CA/56_LosAngeles_CA.tar.gz to predict price of this house: [1995, 3547.5892052348304, 2, 3.0, 1.14, 0, 'y', 'y']
# $516,876.75, took 1,621 ms
#
# Using model LosAngeles_CA/57_LosAngeles_CA.tar.gz to predict price of this house: [1995, 1173.5998700194752, 2, 2.5, 1.43, 2, 'y', 'y']
# $183,085.06, took 1,576 ms
#
# Using model LosAngeles_CA/58_LosAngeles_CA.tar.gz to predict price of this house: [1984, 3200.1456747967395, 6, 2.5, 0.89, 2, 'y', 'n']
# $468,708.28, took 1,648 ms
#
# Using model LosAngeles_CA/59_LosAngeles_CA.tar.gz to predict price of this house: [1974, 3376.2148131122935, 6, 1.0, 1.2, 1, 'n', 'n']
# $396,284.09, took 1,599 ms
#
# Using model LosAngeles_CA/60_LosAngeles_CA.tar.gz to predict price of this house: [1989, 2738.70385178444, 2, 3.0, 0.93, 2, 'n', 'n']
# $376,832.88, took 1,626 ms
#
# Using model LosAngeles_CA/61_LosAngeles_CA.tar.gz to predict price of this house: [1985, 3068.1949337919023, 2, 3.0, 1.24, 3, 'y', 'n']
# $445,407.88, took 1,598 ms
#
# Using model LosAngeles_CA/62_LosAngeles_CA.tar.gz to predict price of this house: [2011, 3176.899035781055, 6, 2.0, 0.51, 0, 'y', 'y']
# $549,192.62, took 1,598 ms
#
# Using model LosAngeles_CA/63_LosAngeles_CA.tar.gz to predict price of this house: [1979, 3692.285694194631, 4, 3.0, 0.84, 3, 'y', 'y']
# $516,339.84, took 1,652 ms
#
# Using model LosAngeles_CA/64_LosAngeles_CA.tar.gz to predict price of this house: [2001, 3756.7270573269443, 5, 2.5, 0.89, 0, 'y', 'n']
# $598,415.38, took 1,625 ms
#
# Using model LosAngeles_CA/65_LosAngeles_CA.tar.gz to predict price of this house: [1979, 2853.1093182345953, 5, 3.0, 1.25, 1, 'y', 'n']
# $381,844.44, took 1,620 ms
#
# Using model LosAngeles_CA/66_LosAngeles_CA.tar.gz to predict price of this house: [1996, 3635.7861034075004, 4, 2.5, 0.69, 1, 'y', 'n']
# $558,350.88, took 1,624 ms
#
# Using model LosAngeles_CA/67_LosAngeles_CA.tar.gz to predict price of this house: [1998, 2598.286610128326, 5, 1.0, 0.99, 0, 'n', 'n']
# $369,047.91, took 1,652 ms
#
# Using model LosAngeles_CA/68_LosAngeles_CA.tar.gz to predict price of this house: [2000, 1863.2359143474766, 2, 2.5, 0.85, 3, 'y', 'n']
# $322,849.75, took 1,623 ms
#
# Using model LosAngeles_CA/69_LosAngeles_CA.tar.gz to predict price of this house: [1992, 2082.617402419849, 2, 1.0, 0.97, 1, 'n', 'n']
# $249,789.08, took 1,623 ms
#
# Using model LosAngeles_CA/70_LosAngeles_CA.tar.gz to predict price of this house: [2001, 1323.1889397512946, 5, 3.0, 0.91, 2, 'y', 'n']
# $266,071.31, took 1,664 ms
#
# Using model LosAngeles_CA/71_LosAngeles_CA.tar.gz to predict price of this house: [1996, 3306.1383796740415, 2, 2.0, 0.59, 3, 'y', 'n']
# $510,594.12, took 1,684 ms
#
# Using model LosAngeles_CA/72_LosAngeles_CA.tar.gz to predict price of this house: [1984, 2617.0267365652207, 5, 1.5, 1.37, 3, 'n', 'y']
# $353,319.09, took 1,653 ms
#
# Using model LosAngeles_CA/73_LosAngeles_CA.tar.gz to predict price of this house: [1990, 2778.6276374573695, 3, 2.5, 1.28, 0, 'y', 'n']
# $385,686.31, took 1,646 ms
#
# Using model LosAngeles_CA/74_LosAngeles_CA.tar.gz to predict price of this house: [1979, 2472.043018214183, 2, 2.0, 0.94, 1, 'y', 'n']
# $279,197.81, took 1,624 ms
#
# Using model LosAngeles_CA/75_LosAngeles_CA.tar.gz to predict price of this house: [2006, 2388.562341429597, 3, 3.0, 1.51, 0, 'n', 'y']
# $389,549.75, took 1,672 ms
#
# Using model LosAngeles_CA/76_LosAngeles_CA.tar.gz to predict price of this house: [1973, 2787.419920215192, 2, 2.5, 0.97, 3, 'y', 'y']
# $327,828.09, took 1,599 ms
#
# Using model LosAngeles_CA/77_LosAngeles_CA.tar.gz to predict price of this house: [1995, 4126.503276000763, 5, 1.5, 1.15, 2, 'n', 'n']
# $623,318.12, took 1,650 ms
#
# Using model LosAngeles_CA/78_LosAngeles_CA.tar.gz to predict price of this house: [1999, 3227.592224877352, 5, 1.5, 0.75, 3, 'n', 'y']
# $509,113.44, took 1,601 ms
#
# Using model LosAngeles_CA/79_LosAngeles_CA.tar.gz to predict price of this house: [1999, 3017.785693699823, 5, 1.0, 1.16, 1, 'n', 'n']
# $453,900.34, took 1,623 ms
#
# Using model LosAngeles_CA/80_LosAngeles_CA.tar.gz to predict price of this house: [1995, 2583.5219826398857, 5, 2.5, 1.24, 0, 'y', 'y']
# $391,342.59, took 1,599 ms
#
# Using model LosAngeles_CA/81_LosAngeles_CA.tar.gz to predict price of this house: [1984, 3230.044734760366, 5, 1.5, 0.81, 1, 'n', 'y']
# $409,609.19, took 1,650 ms
#
# Using model LosAngeles_CA/82_LosAngeles_CA.tar.gz to predict price of this house: [1989, 2546.3358708781643, 5, 2.5, 1.35, 3, 'n', 'n']
# $386,785.28, took 1,599 ms
#
# Using model LosAngeles_CA/83_LosAngeles_CA.tar.gz to predict price of this house: [2003, 2617.770467536431, 3, 1.0, 1.43, 1, 'n', 'n']
# $399,452.41, took 1,623 ms
#
# Using model LosAngeles_CA/84_LosAngeles_CA.tar.gz to predict price of this house: [1990, 2210.313651937159, 4, 1.5, 1.28, 2, 'y', 'y']
# $316,295.88, took 1,699 ms
#
# Using model LosAngeles_CA/85_LosAngeles_CA.tar.gz to predict price of this house: [1984, 4492.408315508181, 6, 2.5, 1.01, 2, 'n', 'n']
# $646,416.00, took 1,628 ms
#
# Using model LosAngeles_CA/86_LosAngeles_CA.tar.gz to predict price of this house: [1986, 3991.4783190232256, 6, 2.0, 0.68, 2, 'n', 'y']
# $562,457.62, took 1,648 ms
#
# Using model LosAngeles_CA/87_LosAngeles_CA.tar.gz to predict price of this house: [1988, 3081.7395562521356, 3, 2.0, 1.1, 1, 'y', 'y']
# $420,218.44, took 1,673 ms
#
# Using model LosAngeles_CA/88_LosAngeles_CA.tar.gz to predict price of this house: [1979, 2534.769568883132, 4, 3.0, 1.19, 2, 'n', 'y']
# $312,950.69, took 1,655 ms
#
# Using model LosAngeles_CA/89_LosAngeles_CA.tar.gz to predict price of this house: [2011, 3185.3143019923364, 5, 2.0, 1.06, 2, 'n', 'y']
# $558,584.88, took 1,670 ms
#
# Using model LosAngeles_CA/90_LosAngeles_CA.tar.gz to predict price of this house: [1999, 2627.6357834456185, 4, 3.0, 1.2, 2, 'n', 'n']
# $429,787.91, took 1,651 ms
#
# Using model LosAngeles_CA/91_LosAngeles_CA.tar.gz to predict price of this house: [2003, 3155.1632899429364, 4, 2.0, 0.88, 0, 'y', 'n']
# $501,101.41, took 1,695 ms
#
# Using model LosAngeles_CA/92_LosAngeles_CA.tar.gz to predict price of this house: [1992, 2836.5504834829785, 4, 1.5, 0.61, 3, 'n', 'y']
# $405,347.97, took 1,680 ms
#
# Using model LosAngeles_CA/93_LosAngeles_CA.tar.gz to predict price of this house: [1993, 2261.420827628359, 4, 1.5, 0.27, 0, 'y', 'y']
# $295,487.44, took 1,694 ms
#
# Using model LosAngeles_CA/94_LosAngeles_CA.tar.gz to predict price of this house: [1999, 3520.8826407166644, 3, 3.0, 1.16, 1, 'n', 'n']
# $541,543.62, took 1,625 ms
#
# Using model LosAngeles_CA/95_LosAngeles_CA.tar.gz to predict price of this house: [1995, 2931.075881472652, 4, 2.5, 0.94, 3, 'n', 'y']
# $453,500.25, took 1,598 ms
#
# Using model LosAngeles_CA/96_LosAngeles_CA.tar.gz to predict price of this house: [2005, 4270.821954629472, 4, 3.0, 1.01, 2, 'y', 'n']
# $723,981.25, took 1,699 ms
#
# Using model LosAngeles_CA/97_LosAngeles_CA.tar.gz to predict price of this house: [1993, 1900.1233785974273, 2, 2.0, 0.84, 1, 'y', 'y']
# $253,245.70, took 1,624 ms
#
# Using model LosAngeles_CA/98_LosAngeles_CA.tar.gz to predict price of this house: [1999, 2522.288495413471, 2, 1.0, 0.89, 1, 'y', 'y']
# $362,675.00, took 1,649 ms
#
# Using model LosAngeles_CA/99_LosAngeles_CA.tar.gz to predict price of this house: [1986, 2979.3085896116645, 2, 2.5, 0.93, 1, 'n', 'y']
# $371,613.19, took 1,600 ms
#
# Using model LosAngeles_CA/100_LosAngeles_CA.tar.gz to predict price of this house: [1986, 4214.056393065488, 4, 3.0, 0.68, 3, 'n', 'y']
# $607,295.44, took 1,597 ms
#
# Using model LosAngeles_CA/101_LosAngeles_CA.tar.gz to predict price of this house: [1986, 4048.799831953522, 2, 3.0, 0.83, 1, 'y', 'y']
# $558,554.44, took 1,625 ms
#
# Using model LosAngeles_CA/102_LosAngeles_CA.tar.gz to predict price of this house: [1993, 2954.649585059921, 5, 2.0, 1.41, 2, 'n', 'n']
# $447,503.09, took 1,623 ms
#
# Using model LosAngeles_CA/103_LosAngeles_CA.tar.gz to predict price of this house: [1991, 2955.9874354830104, 3, 3.0, 1.31, 3, 'y', 'n']
# $467,196.62, took 1,600 ms
#
# Using model LosAngeles_CA/104_LosAngeles_CA.tar.gz to predict price of this house: [1982, 2741.3405473954235, 5, 2.0, 1.03, 2, 'n', 'n']
# $356,353.97, took 1,599 ms
#
# Using model LosAngeles_CA/105_LosAngeles_CA.tar.gz to predict price of this house: [1988, 4686.325521834144, 6, 1.0, 0.49, 2, 'n', 'y']
# $659,954.88, took 1,626 ms
#
# Using model LosAngeles_CA/106_LosAngeles_CA.tar.gz to predict price of this house: [1999, 1880.9854785995185, 6, 1.0, 0.9, 1, 'y', 'n']
# $306,292.47, took 1,649 ms
#
# Using model LosAngeles_CA/107_LosAngeles_CA.tar.gz to predict price of this house: [1987, 3557.057829700473, 4, 3.0, 0.69, 2, 'n', 'y']
# $498,878.88, took 1,623 ms
#
# Using model LosAngeles_CA/108_LosAngeles_CA.tar.gz to predict price of this house: [1991, 3876.99202923715, 5, 1.5, 1.39, 0, 'y', 'y']
# $555,333.62, took 1,624 ms
#
# Using model LosAngeles_CA/109_LosAngeles_CA.tar.gz to predict price of this house: [1989, 2607.0044541389498, 6, 2.0, 0.89, 3, 'y', 'n']
# $410,067.94, took 1,648 ms
#
# Using model LosAngeles_CA/110_LosAngeles_CA.tar.gz to predict price of this house: [1990, 4444.010620351708, 5, 3.0, 1.4, 2, 'y', 'y']
# $686,171.25, took 1,649 ms
#
# Using model LosAngeles_CA/111_LosAngeles_CA.tar.gz to predict price of this house: [1981, 2154.970942248102, 5, 2.5, 1.51, 0, 'n', 'y']
# $243,259.69, took 1,628 ms
#
# Using model LosAngeles_CA/112_LosAngeles_CA.tar.gz to predict price of this house: [2006, 2225.470442996316, 3, 3.0, 0.69, 0, 'n', 'y']
# $352,754.81, took 1,595 ms
#
# Using model LosAngeles_CA/113_LosAngeles_CA.tar.gz to predict price of this house: [1977, 3983.4202393178216, 6, 1.5, 1.35, 3, 'n', 'n']
# $540,193.94, took 1,649 ms
#
# Using model LosAngeles_CA/114_LosAngeles_CA.tar.gz to predict price of this house: [1987, 2391.1928660415806, 4, 2.0, 1.31, 1, 'y', 'n']
# $328,516.16, took 1,600 ms
#
# Using model LosAngeles_CA/115_LosAngeles_CA.tar.gz to predict price of this house: [2005, 3301.2625189933983, 3, 2.5, 1.06, 0, 'n', 'y']
# $508,837.44, took 1,626 ms
#
# Using model LosAngeles_CA/116_LosAngeles_CA.tar.gz to predict price of this house: [1998, 2245.4768417916266, 4, 3.0, 0.7, 0, 'n', 'n']
# $331,638.69, took 1,623 ms
#
# Using model LosAngeles_CA/117_LosAngeles_CA.tar.gz to predict price of this house: [1994, 4416.296319135511, 6, 1.5, 0.88, 0, 'n', 'n']
# $638,843.75, took 1,599 ms
#
# Using model LosAngeles_CA/118_LosAngeles_CA.tar.gz to predict price of this house: [2009, 3832.78275438813, 5, 1.0, 1.22, 1, 'n', 'y']
# $620,665.12, took 1,674 ms
#
# Using model LosAngeles_CA/119_LosAngeles_CA.tar.gz to predict price of this house: [1994, 4080.7803163192493, 3, 3.0, 0.63, 3, 'n', 'n']
# $622,271.81, took 1,651 ms
#
# Using model LosAngeles_CA/120_LosAngeles_CA.tar.gz to predict price of this house: [2004, 3021.8045410006944, 5, 2.0, 0.78, 1, 'y', 'n']
# $507,022.44, took 1,674 ms
#
# Using model LosAngeles_CA/121_LosAngeles_CA.tar.gz to predict price of this house: [1988, 1938.4815976718153, 5, 1.5, 0.87, 1, 'n', 'n']
# $240,356.39, took 1,597 ms
#
# Using model LosAngeles_CA/122_LosAngeles_CA.tar.gz to predict price of this house: [1987, 3817.8855800450365, 6, 2.0, 1.28, 1, 'y', 'n']
# $561,134.25, took 1,651 ms
#
# Using model LosAngeles_CA/123_LosAngeles_CA.tar.gz to predict price of this house: [1993, 3014.1349394020694, 2, 1.0, 1.64, 2, 'y', 'y']
# $433,149.59, took 1,649 ms
#
# Using model LosAngeles_CA/124_LosAngeles_CA.tar.gz to predict price of this house: [1994, 3091.5969543660954, 5, 2.0, 0.84, 0, 'y', 'n']
# $455,975.28, took 1,653 ms
#
# Using model LosAngeles_CA/125_LosAngeles_CA.tar.gz to predict price of this house: [2004, 2141.632301217137, 5, 2.0, 1.42, 3, 'n', 'n']
# $392,043.12, took 1,620 ms
#
# Using model LosAngeles_CA/126_LosAngeles_CA.tar.gz to predict price of this house: [1990, 2978.1850279045243, 6, 1.0, 1.42, 3, 'y', 'n']
# $464,433.19, took 1,647 ms
#
# Using model LosAngeles_CA/127_LosAngeles_CA.tar.gz to predict price of this house: [1979, 1480.8148630159874, 6, 3.0, 0.84, 1, 'n', 'y']
# $151,665.94, took 1,600 ms
#
# Using model LosAngeles_CA/128_LosAngeles_CA.tar.gz to predict price of this house: [2003, 3003.0658250419133, 6, 1.5, 0.9, 1, 'y', 'n']
# $502,561.28, took 1,677 ms
#
# Using model LosAngeles_CA/129_LosAngeles_CA.tar.gz to predict price of this house: [2016, 3340.7128470552725, 4, 1.5, 1.17, 3, 'y', 'n']
# $631,363.88, took 1,647 ms
#
# Using model LosAngeles_CA/130_LosAngeles_CA.tar.gz to predict price of this house: [1972, 4234.875022768272, 3, 1.5, 0.71, 3, 'y', 'n']
# $538,019.00, took 1,598 ms
#
# Using model LosAngeles_CA/131_LosAngeles_CA.tar.gz to predict price of this house: [1993, 2950.3126966789096, 3, 3.0, 0.99, 3, 'n', 'y']
# $446,023.66, took 1,598 ms
#
# Using model LosAngeles_CA/132_LosAngeles_CA.tar.gz to predict price of this house: [1982, 2505.230235900262, 3, 1.0, 1.08, 0, 'n', 'n']
# $261,496.28, took 1,575 ms
#
# Using model LosAngeles_CA/133_LosAngeles_CA.tar.gz to predict price of this house: [1990, 3154.297994918771, 5, 1.0, 0.94, 3, 'n', 'y']
# $450,032.56, took 1,649 ms
#
# Using model LosAngeles_CA/134_LosAngeles_CA.tar.gz to predict price of this house: [1989, 3756.105713427117, 6, 1.5, 1.64, 2, 'y', 'n']
# $573,641.25, took 1,625 ms
#
# Using model LosAngeles_CA/135_LosAngeles_CA.tar.gz to predict price of this house: [1999, 3594.0778874137623, 3, 2.0, 1.01, 0, 'y', 'y']
# $535,570.19, took 1,598 ms
#
# Using model LosAngeles_CA/136_LosAngeles_CA.tar.gz to predict price of this house: [1983, 3032.8489606088556, 4, 2.0, 1.24, 2, 'n', 'y']
# $393,930.81, took 1,649 ms
#
# Using model LosAngeles_CA/137_LosAngeles_CA.tar.gz to predict price of this house: [1998, 2847.178895408229, 2, 1.0, 1.07, 3, 'n', 'n']
# $424,058.28, took 1,575 ms
#
# Using model LosAngeles_CA/138_LosAngeles_CA.tar.gz to predict price of this house: [1986, 4143.162707792758, 4, 1.5, 1.27, 3, 'n', 'n']
# $589,424.31, took 1,649 ms
#
# Using model LosAngeles_CA/139_LosAngeles_CA.tar.gz to predict price of this house: [1988, 3066.714138507069, 5, 3.0, 0.83, 3, 'n', 'y']
# $454,370.12, took 1,601 ms
#
# Using model LosAngeles_CA/140_LosAngeles_CA.tar.gz to predict price of this house: [1997, 2143.605660761587, 5, 1.5, 1.57, 2, 'n', 'n']
# $339,377.31, took 1,624 ms
#
# Using model LosAngeles_CA/141_LosAngeles_CA.tar.gz to predict price of this house: [1983, 2436.669016279293, 5, 2.5, 0.91, 3, 'y', 'y']
# $348,320.22, took 1,672 ms
#
# Using model LosAngeles_CA/142_LosAngeles_CA.tar.gz to predict price of this house: [2001, 2256.3583935194224, 4, 2.0, 1.23, 1, 'n', 'n']
# $355,267.69, took 1,599 ms
#
# Using model LosAngeles_CA/143_LosAngeles_CA.tar.gz to predict price of this house: [1993, 4838.66351730158, 4, 1.0, 0.97, 1, 'n', 'y']
# $682,920.19, took 1,626 ms
#
# Using model LosAngeles_CA/144_LosAngeles_CA.tar.gz to predict price of this house: [1993, 2472.7214633260855, 3, 1.5, 0.88, 1, 'y', 'n']
# $347,651.84, took 1,596 ms
#
# Using model LosAngeles_CA/145_LosAngeles_CA.tar.gz to predict price of this house: [1989, 2879.10032294863, 5, 1.0, 1.13, 2, 'n', 'n']
# $398,117.25, took 1,625 ms
#
# Using model LosAngeles_CA/146_LosAngeles_CA.tar.gz to predict price of this house: [1998, 2689.124519337002, 5, 1.0, 0.99, 2, 'y', 'y']
# $424,589.84, took 1,650 ms
#
# Using model LosAngeles_CA/147_LosAngeles_CA.tar.gz to predict price of this house: [1987, 3944.55020721117, 5, 1.0, 1.04, 2, 'y', 'n']
# $567,686.00, took 1,648 ms
#
# Using model LosAngeles_CA/148_LosAngeles_CA.tar.gz to predict price of this house: [1986, 2821.15533041528, 2, 1.5, 1.27, 0, 'y', 'n']
# $349,487.12, took 1,624 ms
#
# Using model LosAngeles_CA/149_LosAngeles_CA.tar.gz to predict price of this house: [2005, 3908.0081176162494, 3, 2.0, 0.96, 0, 'y', 'y']
# $611,357.88, took 1,625 ms
#
# Using model LosAngeles_CA/150_LosAngeles_CA.tar.gz to predict price of this house: [1993, 2254.0202221859467, 5, 1.0, 0.74, 0, 'y', 'y']
# $302,762.38, took 1,625 ms
#
# Using model LosAngeles_CA/151_LosAngeles_CA.tar.gz to predict price of this house: [1996, 2803.9635316197055, 6, 1.0, 0.65, 3, 'n', 'n']
# $436,276.50, took 1,625 ms
#
# Using model LosAngeles_CA/152_LosAngeles_CA.tar.gz to predict price of this house: [1988, 2373.513298460616, 4, 3.0, 0.75, 2, 'y', 'y']
# $345,117.06, took 1,598 ms
#
# Using model LosAngeles_CA/153_LosAngeles_CA.tar.gz to predict price of this house: [2012, 2483.5905513248017, 5, 1.0, 1.15, 0, 'y', 'n']
# $441,346.97, took 1,649 ms
#
# Using model LosAngeles_CA/154_LosAngeles_CA.tar.gz to predict price of this house: [1981, 3087.058218757841, 5, 1.5, 0.78, 1, 'y', 'n']
# $398,280.88, took 1,607 ms
#
# Using model LosAngeles_CA/155_LosAngeles_CA.tar.gz to predict price of this house: [1980, 3209.7361055477886, 4, 2.0, 0.76, 1, 'n', 'n']
# $390,777.47, took 1,614 ms
#
# Using model LosAngeles_CA/156_LosAngeles_CA.tar.gz to predict price of this house: [1994, 2165.7800821279693, 2, 3.0, 1.2, 0, 'y', 'n']
# $309,763.44, took 1,625 ms
#
# Using model LosAngeles_CA/157_LosAngeles_CA.tar.gz to predict price of this house: [1996, 3207.0298850154413, 2, 2.5, 1.09, 2, 'y', 'n']
# $496,169.34, took 1,623 ms
#
# Using model LosAngeles_CA/158_LosAngeles_CA.tar.gz to predict price of this house: [1984, 2478.7322226997653, 3, 2.0, 1.02, 1, 'n', 'y']
# $289,004.88, took 1,625 ms
#
# Using model LosAngeles_CA/159_LosAngeles_CA.tar.gz to predict price of this house: [1980, 3935.478397282588, 2, 1.5, 1.31, 1, 'n', 'n']
# $484,107.44, took 1,652 ms
#
# Using model LosAngeles_CA/160_LosAngeles_CA.tar.gz to predict price of this house: [1999, 3052.1768405545763, 2, 2.0, 0.86, 2, 'y', 'n']
# $476,655.03, took 1,621 ms
#
# Using model LosAngeles_CA/161_LosAngeles_CA.tar.gz to predict price of this house: [2006, 1951.3579741595279, 4, 2.0, 1.34, 0, 'n', 'y']
# $315,139.03, took 1,702 ms
#
# Using model LosAngeles_CA/162_LosAngeles_CA.tar.gz to predict price of this house: [1989, 3982.9364892292288, 2, 1.0, 1.0, 2, 'y', 'y']
# $550,804.38, took 1,671 ms
#
# Using model LosAngeles_CA/163_LosAngeles_CA.tar.gz to predict price of this house: [1996, 2269.8956720286465, 3, 1.0, 0.79, 3, 'n', 'n']
# $331,599.78, took 1,649 ms
#
# Using model LosAngeles_CA/164_LosAngeles_CA.tar.gz to predict price of this house: [1992, 4314.309283792467, 5, 1.5, 0.9, 0, 'n', 'y']
# $599,578.88, took 1,675 ms
#
# Using model LosAngeles_CA/165_LosAngeles_CA.tar.gz to predict price of this house: [1996, 2692.522190084914, 5, 1.5, 0.84, 3, 'n', 'y']
# $415,006.78, took 1,698 ms
#
# Using model LosAngeles_CA/166_LosAngeles_CA.tar.gz to predict price of this house: [2015, 3575.9812951470412, 2, 2.5, 1.28, 3, 'y', 'n']
# $660,845.19, took 1,648 ms
#
# Using model LosAngeles_CA/167_LosAngeles_CA.tar.gz to predict price of this house: [2004, 1257.1504651212526, 2, 1.0, 1.07, 2, 'n', 'y']
# $192,831.09, took 1,598 ms
#
# Using model LosAngeles_CA/168_LosAngeles_CA.tar.gz to predict price of this house: [1996, 3048.8184641233192, 2, 3.0, 0.9, 1, 'y', 'y']
# $456,807.72, took 1,599 ms
#
# Using model LosAngeles_CA/169_LosAngeles_CA.tar.gz to predict price of this house: [2001, 2688.6999908313724, 5, 1.0, 1.35, 1, 'n', 'y']
# $410,845.12, took 1,625 ms
#
# Using model LosAngeles_CA/170_LosAngeles_CA.tar.gz to predict price of this house: [1997, 3466.8842930549363, 2, 1.0, 1.01, 3, 'n', 'n']
# $512,035.53, took 1,648 ms
#
# Using model LosAngeles_CA/171_LosAngeles_CA.tar.gz to predict price of this house: [1992, 3310.3341737127507, 2, 1.0, 0.83, 3, 'y', 'y']
# $475,171.06, took 1,628 ms
#
# Using model LosAngeles_CA/172_LosAngeles_CA.tar.gz to predict price of this house: [2007, 3430.3248519484814, 6, 2.0, 0.95, 0, 'n', 'n']
# $560,967.69, took 1,619 ms
#
# Using model LosAngeles_CA/173_LosAngeles_CA.tar.gz to predict price of this house: [2006, 3364.189664987897, 3, 3.0, 0.88, 0, 'n', 'n']
# $533,546.00, took 1,689 ms
#
# Using model LosAngeles_CA/174_LosAngeles_CA.tar.gz to predict price of this house: [2004, 3415.5145060923655, 4, 2.0, 0.97, 2, 'y', 'n']
# $574,765.00, took 1,611 ms
#
# Using model LosAngeles_CA/175_LosAngeles_CA.tar.gz to predict price of this house: [1993, 3364.5564341342797, 4, 1.0, 1.04, 1, 'y', 'n']
# $486,316.50, took 1,599 ms
#
# Using model LosAngeles_CA/176_LosAngeles_CA.tar.gz to predict price of this house: [1999, 3132.3643967302737, 3, 1.5, 1.1, 2, 'y', 'n']
# $493,771.31, took 1,598 ms
#
# Using model LosAngeles_CA/177_LosAngeles_CA.tar.gz to predict price of this house: [1998, 2360.9995946928075, 6, 3.0, 0.73, 0, 'n', 'n']
# $366,877.81, took 1,600 ms
#
# Using model LosAngeles_CA/178_LosAngeles_CA.tar.gz to predict price of this house: [1991, 2847.3248594686015, 5, 2.0, 0.84, 1, 'y', 'y']
# $412,779.72, took 1,603 ms
#
# Using model LosAngeles_CA/179_LosAngeles_CA.tar.gz to predict price of this house: [1999, 2981.4115607766594, 5, 2.0, 1.21, 1, 'n', 'n']
# $463,587.28, took 1,622 ms
#
# Using model LosAngeles_CA/180_LosAngeles_CA.tar.gz to predict price of this house: [2002, 3790.581220370346, 4, 2.0, 1.2, 3, 'n', 'n']
# $619,782.44, took 1,648 ms
#
# Using model LosAngeles_CA/181_LosAngeles_CA.tar.gz to predict price of this house: [1989, 3384.729529909833, 5, 2.5, 0.9, 3, 'y', 'y']
# $520,588.88, took 1,599 ms
#
# Using model LosAngeles_CA/182_LosAngeles_CA.tar.gz to predict price of this house: [1987, 3760.4514010445846, 4, 3.0, 0.49, 2, 'n', 'y']
# $526,675.44, took 1,623 ms
#
# Using model LosAngeles_CA/183_LosAngeles_CA.tar.gz to predict price of this house: [1999, 3674.567822834594, 3, 3.0, 1.06, 0, 'n', 'n']
# $549,243.00, took 1,653 ms
#
# Using model LosAngeles_CA/184_LosAngeles_CA.tar.gz to predict price of this house: [1994, 1685.1437302140037, 5, 3.0, 0.98, 2, 'n', 'y']
# $262,674.16, took 1,676 ms
#
# Using model LosAngeles_CA/185_LosAngeles_CA.tar.gz to predict price of this house: [1994, 2126.048545473217, 4, 2.5, 0.95, 3, 'y', 'y']
# $346,549.88, took 1,645 ms
#
# Using model LosAngeles_CA/186_LosAngeles_CA.tar.gz to predict price of this house: [1992, 4861.22298327819, 4, 3.0, 0.9, 0, 'y', 'n']
# $720,553.00, took 1,648 ms
#
# Using model LosAngeles_CA/187_LosAngeles_CA.tar.gz to predict price of this house: [2015, 2539.540506505743, 3, 2.0, 0.93, 2, 'n', 'y']
# $461,056.22, took 1,627 ms
#
# Using model LosAngeles_CA/188_LosAngeles_CA.tar.gz to predict price of this house: [2003, 2609.0097733729976, 3, 3.0, 1.2, 1, 'y', 'y']
# $437,304.78, took 1,621 ms
#
# Using model LosAngeles_CA/189_LosAngeles_CA.tar.gz to predict price of this house: [1978, 3510.916727530348, 6, 2.0, 1.04, 3, 'y', 'y']
# $489,910.12, took 1,649 ms
#
# Using model LosAngeles_CA/190_LosAngeles_CA.tar.gz to predict price of this house: [2002, 3464.392526294474, 2, 2.0, 0.75, 0, 'n', 'n']
# $504,292.50, took 1,649 ms
#
# Using model LosAngeles_CA/191_LosAngeles_CA.tar.gz to predict price of this house: [2005, 3166.5604922188795, 3, 2.5, 0.69, 1, 'n', 'n']
# $502,844.12, took 1,600 ms
#
# Using model LosAngeles_CA/192_LosAngeles_CA.tar.gz to predict price of this house: [2000, 2574.348346620504, 3, 1.0, 1.29, 1, 'y', 'n']
# $395,761.97, took 1,654 ms
#
# Using model LosAngeles_CA/193_LosAngeles_CA.tar.gz to predict price of this house: [1988, 2321.252115429472, 6, 1.0, 1.28, 1, 'y', 'n']
# $325,218.34, took 1,643 ms
#
# Using model LosAngeles_CA/194_LosAngeles_CA.tar.gz to predict price of this house: [1974, 3257.334233271575, 4, 2.0, 0.39, 1, 'y', 'n']
# $382,918.81, took 1,674 ms
#
# Using model LosAngeles_CA/195_LosAngeles_CA.tar.gz to predict price of this house: [1990, 3684.255110804168, 5, 2.0, 0.82, 0, 'y', 'n']
# $525,926.00, took 1,675 ms
#
# Using model LosAngeles_CA/196_LosAngeles_CA.tar.gz to predict price of this house: [1999, 2988.1551830391027, 3, 2.0, 1.53, 0, 'y', 'y']
# $451,640.69, took 1,598 ms
#
# Using model LosAngeles_CA/197_LosAngeles_CA.tar.gz to predict price of this house: [1998, 3008.2679883660944, 5, 2.0, 0.9, 0, 'y', 'n']
# $463,633.94, took 1,650 ms
#
# Using model LosAngeles_CA/198_LosAngeles_CA.tar.gz to predict price of this house: [1981, 1699.206868564134, 6, 2.0, 0.95, 1, 'y', 'n']
# $206,821.28, took 1,649 ms
#
# Using model LosAngeles_CA/199_LosAngeles_CA.tar.gz to predict price of this house: [1984, 3618.592564789929, 3, 1.5, 0.79, 0, 'n', 'y']
# $436,680.12, took 1,624 ms

# %% [markdown]
# #### CloudWatch charts for LoadedModelCount,MemoryUtilization and ModelCacheHit metrics will be similar to charts below.
#
# ![](cw_charts/ModelCountMemUtilization.png)
#
# “LoadedModelCount” continuously increases, as more models are invoked, till it levels off at 121.  “MemoryUtilization” of the container also increased correspondingly to around 79%.  This shows that the instance chosen to host the endpoint, could only maintain 121 models in memory, when 200 model invocations are made.
#
# ![](cw_charts/ModelCountMemUtilizationCacheHit.png)
#
# As the number of models loaded to the container memory increase, the ModelCacheHit improves.  When the same 100 models are invoked the second time, the ModelCacheHit reaches 1.  When new models, not yet loaded are invoked the ModelCacheHit decreases again.

# %% [markdown]
# ## Section 9 - Explore granular access to the target models of MME <a id='Finegrain-control-invoke-models'></a>
#
# If the role attached to this notebook instance allows invoking SageMaker endpoints, it is able to invoke all models hosted on the MME.  Using IAM conditional keys, you can restrict this model invocation access to specific models.  To explore this, you will create a new IAM role and IAM policy with conditional key to restrict access to a single model.  Assume this new role and verify that only a single target model can be invoked.
#
# Note that to execute this section, the role attached to the notebook instance should allow the following actions :
#     "iam:CreateRole",
#     "iam:CreatePolicy",
#     "iam:AttachRolePolicy",
#     "iam:UpdateAssumeRolePolicy"
#
# If this is not the case, please work with the Administrator of this AWS account to ensure this.

# %%
iam_client = boto3.client('iam')

# %%
#Create a new role that can be assumed by this notebook.  The roles should allow access to only a single model.

path='/'

role_name="{}{}".format('allow_invoke_ny_model_role', strftime('%Y-%m-%d-%H-%M-%S', gmtime()))
description='Role that allows invoking a single model'

action_string = "sts:AssumeRole"
    
trust_policy={
  "Version": "2012-10-17",
  "Statement": [
    {
      "Sid": "statement1",
      "Effect": "Allow",
      "Principal": {
        "AWS": role
      },
      "Action": "sts:AssumeRole"
    }
  ]
}

# %%
response = iam_client.create_role(
    Path=path,
    RoleName=role_name,
    AssumeRolePolicyDocument=json.dumps(trust_policy),
    Description=description,
    MaxSessionDuration=3600
)

# %%
role_arn=response['Role']['Arn']
print("Role arn is :", role_arn)

# %%
endpoint_resource_arn = "arn:aws:sagemaker:{}:{}:endpoint/{}".format(REGION, ACCOUNT_ID, endpoint_name)
print("Endpoint arn is :", endpoint_resource_arn)

# %%
##Create the IAM policy with the IAM condition key
policy_name = "{}{}".format('allow_invoke_ny_model_policy', strftime('%Y-%m-%d-%H-%M-%S', gmtime()))
managed_policy = {
    "Version": "2012-10-17",
    "Statement": [
        {
            "Sid": "SageMakerAccess",
            "Action": "sagemaker:InvokeEndpoint",
            "Effect": "Allow",
            "Resource":endpoint_resource_arn,
            "Condition": {
                "StringLike": {
                    "sagemaker:TargetModel": ["NewYork_NY/*"]
                }
            }
        }
    ]
}

response = iam_client.create_policy(
  PolicyName=policy_name,
  PolicyDocument=json.dumps(managed_policy)
)

# %%
policy_arn=response['Policy']['Arn']

# %%
##Attach policy to role
iam_client.attach_role_policy(
    PolicyArn=policy_arn,
    RoleName=role_name
)

# %%
## Invoke with the role that has access to only NY model
sts_connection = boto3.client('sts')
assumed_role_limited_access = sts_connection.assume_role(
    RoleArn=role_arn,
    RoleSessionName="MME_Invoke_NY_Model"
)
assumed_role_limited_access['AssumedRoleUser']['Arn']

# %%
trust_policy={
  "Version": "2012-10-17",
  "Statement": [
    {
      "Sid": "statement1",
      "Effect": "Allow",
      "Principal": {
        "AWS": role
      },
      "Action": "sts:AssumeRole"
    },
    {
      "Sid": "statement2",
      "Effect": "Allow",
      "Principal": {
          "AWS": assumed_role_limited_access['AssumedRoleUser']['Arn']
      },
      "Action": "sts:AssumeRole"
    }  
  ]
}

# %%
iam_client.update_assume_role_policy(
    RoleName=role_name,
    PolicyDocument=json.dumps(trust_policy)
)

# %%
ACCESS_KEY = assumed_role_limited_access['Credentials']['AccessKeyId']
SECRET_KEY = assumed_role_limited_access['Credentials']['SecretAccessKey']
SESSION_TOKEN = assumed_role_limited_access['Credentials']['SessionToken']

runtime_sm_client_with_assumed_role = boto3.client(
    service_name='sagemaker-runtime', 
    aws_access_key_id=ACCESS_KEY,
    aws_secret_access_key=SECRET_KEY,
    aws_session_token=SESSION_TOKEN,
)

# %%
 sagemakerSessionAssumedRole = sagemaker.Session(sagemaker_runtime_client=runtime_sm_client_with_assumed_role)

# %%
predictorAssumedRole = Predictor(
    endpoint_name=endpoint_name,
    sagemaker_session=sagemakerSessionAssumedRole,
    serializer=csv_serializer)

# %%
full_model_name = 'NewYork_NY/NewYork_NY.tar.gz'
predict_one_house_value(gen_random_house()[:-1], full_model_name,predictorAssumedRole)

# %%
##This should fail with "AccessDeniedException" since the assumed role does not have access to Chicago model
full_model_name = 'Chicago_IL/Chicago_IL.tar.gz'
predict_one_house_value(gen_random_house()[:-1], full_model_name,predictorAssumedRole)

# %% [markdown]
# ## Clean up<a id='CleanUp'></a>
# Clean up the endpoint to avoid unneccessary costs.

# %%
#Delete the endpoint and underlying model
predictor.delete_model() 
predictor.delete_endpoint()
for t in preprocessor_transformers:
    t.delete_model()

# %%
#Delete the IAM Role
iam_client.detach_role_policy(
    PolicyArn=policy_arn,
    RoleName=role_name
)
iam_client.delete_role(RoleName=role_name)

# %%
#Delete the IAM Policy
iam_client.delete_policy(PolicyArn=policy_arn)
